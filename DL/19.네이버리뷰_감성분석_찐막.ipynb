# %%
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from konlpy.tag import Okt
import re
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train_df = pd.read_csv("./data/ratings_train.txt", sep = "\t")

# %%
test_df = pd.read_csv("./data/ratings_test.txt", sep = "\t")

# %%
train_df.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
test_df.head()
# Out:
#         id                                           document  label
# 0  6270596                                                굳 ㅋ      1
# 1  9274899                               GDNTOPCLASSINTHECLUB      0
# 2  8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3  6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4  6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0

# %%
train_df.shape, test_df.shape
# Out:
# ((150000, 3), (50000, 3))

# %%
# 결측치 확인
train_df.isna().sum()
# Out:
# id          0
# document    5
# label       0
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# id          0
# document    3
# label       0
# dtype: int64

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        150000 non-null  int64
#  1   document  149995 non-null  object
#  2   label     150000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 3.4+ MB

# %%
# 결측치 제거
train_df = train_df.dropna(subset = ["document"])
test_df = test_df.dropna(subset = ["document"])

# %%
train_df.shape, test_df.shape
# Out:
# ((149995, 3), (49997, 3))

# %%
# 종속변수 확인
np.unique(train_df["label"], return_counts = True)
# Out:
# (array([0, 1], dtype=int64), array([75170, 74825], dtype=int64))

# %% [markdown]
# # 데이터 전처리

# %%
# 한글 이외의 문자들 제거
train_df["document"] = train_df["document"].map(lambda x:re.sub("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","",x))
test_df["document"] = test_df["document"].map(lambda x:re.sub("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","",x))

# %%
train_df.head()
# Out:
#          id                                           document  label
# 0   9976970                                  아 더빙 진짜 짜증나네요 목소리      0
# 1   3819312                         흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                          교도소 이야기구먼 솔직히 재미는 없다평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...      1

# %%
test_df.head()
# Out:
#         id                                   document  label
# 0  6270596                                        굳 ㅋ      1
# 1  9274899                                                 0
# 2  8544678           뭐야 이 평점들은 나쁘진 않지만 점 짜리는 더더욱 아니잖아      0
# 3  6825595                  지루하지는 않은데 완전 막장임 돈주고 보기에는      0
# 4  6723715  만 아니었어도 별 다섯 개 줬을텐데 왜 로 나와서 제 심기를 불편하게 하죠      0

# %%
train_df = train_df[train_df["document"].map(lambda x: len(x.strip()) >= 1)]
test_df = test_df[test_df["document"].map(lambda x: len(x.strip()) >= 1)]

# %%
train_df.shape, test_df.shape
# Out:
# ((148740, 3), (49575, 3))

# %%
# 중복 데이터 확인
train_df[train_df["document"].duplicated(keep = False)].sort_values("document")
# Out:
#              id               document  label
# 46599   9682597      그리고 내 감정을 불러 일으켰다      1
# 43436   9582856      그리고 내 감정을 불러 일으켰다      1
# 123713  9582855      그리고 내 감정을 불러 일으켰다      1
# 93364    171409               가입  추천바람      1
# 138373   171407               가입  추천바람      1
# ...         ...                    ...    ...
# 57831   3906478                   흥미진진      1
# 8446    5158304        힐러리 더프의 매력에 빠지다      1
# 72688   5153363        힐러리 더프의 매력에 빠지다      1
# 26889   7971814                    힘들다      0
# 122612  7415842                    힘들다      0
#
# [6449 rows x 3 columns]

# %%
# 중복 제거
train_df = train_df.drop_duplicates(subset = ["document"], keep = "first")
test_df = test_df.drop_duplicates(subset = ["document"], keep = "first")

# %%
train_df.shape, test_df.shape
# Out:
# ((143660, 3), (48403, 3))

# %% [markdown]
# # 토큰화

# %%
okt = Okt()

# %%
okt.morphs("아 더빙 진짜 짜증나네요 목소리", stem = False)
# Out:
# ['아', '더빙', '진짜', '짜증나네요', '목소리']

# %%
okt.morphs("아 더빙 진짜 짜증나네요 목소리", stem = True)
# Out:
# ['아', '더빙', '진짜', '짜증나다', '목소리']

# %%
okt.nouns("아 더빙 진짜 짜증나네요 목소리")
# Out:
# ['더빙', '진짜', '목소리']

# %%
okt.pos("아 더빙 진짜 짜증나네요 목소리")
# Out:
# [('아', 'Exclamation'),
#  ('더빙', 'Noun'),
#  ('진짜', 'Noun'),
#  ('짜증나네요', 'Adjective'),
#  ('목소리', 'Noun')]

# %%
# 강사님 파일 받아옴
train_df.to_csv("nsmc_ratings_train_pre.csv", index = False)
test_df.to_csv("nsmc_ratings_test_pre.csv", index = False)

# %%
# 받아온 파일 읽어서 저장함 
train_df = pd.read_csv("./data/nsmc_ratings_train_pre.csv")
test_df = pd.read_csv("./data/nsmc_ratings_test_pre.csv")

# %%
train_df.head()
# Out:
#          id                                           document  label  \
# 0   9976970                                  아 더빙 진짜 짜증나네요 목소리      0
# 1   3819312                         흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                          교도소 이야기구먼 솔직히 재미는 없다평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...      1
#
#                                                token
# 0                   ['아', '더빙', '진짜', '짜증나다', '목소리']
# 1  ['흠', '포스터', '보고', '초딩', '영화', '줄', '오버', '연기'...
# 2  ['너', '무재', '밓었', '다그', '래서', '보다', '추천', '한',...
# 3  ['교도소', '이야기', '구먼', '솔직하다', '재미', '는', '없다', ...
# 4  ['사이', '몬페', '그', '의', '익살스럽다', '연기', '가', '돋보...

# %%
test_df.head()
# Out:
#         id                                   document  label  \
# 0  6270596                                        굳 ㅋ      1
# 1  8544678           뭐야 이 평점들은 나쁘진 않지만 점 짜리는 더더욱 아니잖아      0
# 2  6825595                  지루하지는 않은데 완전 막장임 돈주고 보기에는      0
# 3  6723715  만 아니었어도 별 다섯 개 줬을텐데 왜 로 나와서 제 심기를 불편하게 하죠      0
# 4  7898805                          음악이 주가 된 최고의 음악영화      1
#
#                                                token
# 0                                        ['굳다', 'ㅋ']
# 1  ['뭐', '야', '이', '평점', '들', '은', '나쁘다', '않다', '...
# 2  ['지루하다', '않다', '완전', '막장', '임', '돈', '주다', '보기...
# 3  ['만', '아니다', '별', '다섯', '개', '주다', '왜', '로', '...
# 4     ['음악', '이', '주가', '되다', '최고', '의', '음악', '영화']

# %%
type(train_df.loc[0, "token"])
# Out:
# str

# %%
train_df.loc[0, "token"]
# Out:
# "['아', '더빙', '진짜', '짜증나다', '목소리']"

# %%
train_df["token"] = train_df["token"].map(lambda x: eval(x))
test_df["token"] = test_df["token"].map(lambda x: eval(x))

# %%
train_df.shape, test_df.shape
# Out:
# ((143660, 4), (48403, 4))

# %%
train_df["token"] = train_df["token"].map(lambda x: [i for i in x if len(i) > 1])
test_df["token"] = test_df["token"].map(lambda x: [i for i in x if len(i) > 1])

# %%
train_df.head()
# Out:
#          id                                           document  label  \
# 0   9976970                                  아 더빙 진짜 짜증나네요 목소리      0
# 1   3819312                         흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                          교도소 이야기구먼 솔직히 재미는 없다평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...      1
#
#                                                token
# 0                                [더빙, 진짜, 짜증나다, 목소리]
# 1             [포스터, 보고, 초딩, 영화, 오버, 연기, 조차, 가볍다, 않다]
# 2                           [무재, 밓었, 다그, 래서, 보다, 추천]
# 3               [교도소, 이야기, 구먼, 솔직하다, 재미, 없다, 평점, 조정]
# 4  [사이, 몬페, 익살스럽다, 연기, 돋보이다, 영화, 스파이더맨, 에서, 늙다, 보...

# %%
train_df = train_df[train_df["token"].map(lambda x:len(x) > 0)]
test_df = test_df[test_df["token"].map(lambda x:len(x) > 0)]

# %%
train_df.shape, test_df.shape
# Out:
# ((143319, 4), (48260, 4))

# %% [markdown]
# # 정수인코딩

# %%
tokenizer = Tokenizer()

# %%
# 단어 집합 생성
# 등장 빈도 수가 높은 순서대로 정수값 부여
tokenizer.fit_on_texts(train_df["token"])

# %%
# 단어 집합
tokenizer.word_index
# Out:
# {'영화': 1,
#  '보다': 2,
#  '하다': 3,
#  '없다': 4,
#  '이다': 5,
#  '있다': 6,
#  '좋다': 7,
#  '너무': 8,
#  '정말': 9,
#  '되다': 10,
#  '재밌다': 11,
#  '같다': 12,
#  '진짜': 13,
#  '으로': 14,
#  '아니다': 15,
#  '않다': 16,
#  '에서': 17,
#  '만들다': 18,
#  '나오다': 19,
#  '연기': 20,
#  '평점': 21,
#  '최고': 22,
#  '스토리': 23,
#  '생각': 24,
#  '드라마': 25,
#  '사람': 26,
#  '감동': 27,
#  '보고': 28,
#  '이렇다': 29,
#  '아깝다': 30,
#  '배우': 31,
#  'ㅋㅋ': 32,
#  '감독': 33,
#  '그냥': 34,
#  '재미있다': 35,
#  '재미': 36,
#  '시간': 37,
#  '내용': 38,
#  '까지': 39,
#  '주다': 40,
#  '자다': 41,
#  '하고': 42,
#  '지루하다': 43,
#  '재미없다': 44,
#  '쓰레기': 45,
#  '모르다': 46,
#  '가다': 47,
#  '들다': 48,
#  '그렇다': 49,
#  '싶다': 50,
#  '작품': 51,
#  '사랑': 52,
#  '알다': 53,
#  '하나': 54,
#  '다시': 55,
#  '마지막': 56,
#  '정도': 57,
#  '이건': 58,
#  '오다': 59,
#  '완전': 60,
#  'ㅠㅠ': 61,
#  '많다': 62,
#  '처음': 63,
#  'ㅋㅋㅋ': 64,
#  '장면': 65,
#  '액션': 66,
#  '주인공': 67,
#  '이렇게': 68,
#  '안되다': 69,
#  '차다': 70,
#  '나다': 71,
#  '이야기': 72,
#  '지금': 73,
#  '최악': 74,
#  '넘다': 75,
#  '느낌': 76,
#  '연출': 77,
#  'ㅡㅡ': 78,
#  '인데': 79,
#  '좋아하다': 80,
#  '명작': 81,
#  '그리고': 82,
#  '받다': 83,
#  '역시': 84,
#  '별로': 85,
#  '많이': 86,
#  '남다': 87,
#  '이해': 88,
#  '이런': 89,
#  '이영화': 90,
#  '느끼다': 91,
#  '괜찮다': 92,
#  '라고': 93,
#  '버리다': 94,
#  '이나': 95,
#  '때문': 96,
#  '여자': 97,
#  '부터': 98,
#  '먹다': 99,
#  '아름답다': 100,
#  '해주다': 101,
#  '보기': 102,
#  '이고': 103,
#  '무슨': 104,
#  '에게': 105,
#  '기억': 106,
#  '결말': 107,
#  'ㅎㅎ': 108,
#  '아쉽다': 109,
#  '마음': 110,
#  '소재': 111,
#  '뻔하다': 112,
#  '인생': 113,
#  '끄다': 114,
#  '보여주다': 115,
#  '어떻다': 116,
#  '없이': 117,
#  '수준': 118,
#  '어리다': 119,
#  '무섭다': 120,
#  '현실': 121,
#  '맞다': 122,
#  '한번': 123,
#  '가장': 124,
#  '웃기다': 125,
#  '반전': 126,
#  '매력': 127,
#  '재다': 128,
#  '되어다': 129,
#  '전개': 130,
#  '라는': 131,
#  '한국': 132,
#  '남자': 133,
#  '끝나다': 134,
#  '가슴': 135,
#  '낮다': 136,
#  '말다': 137,
#  '아이': 138,
#  '죽다': 139,
#  '슬프다': 140,
#  '음악': 141,
#  '유치하다': 142,
#  '높다': 143,
#  '다른': 144,
#  '멋지다': 145,
#  '원작': 146,
#  '늘다': 147,
#  '인간': 148,
#  '솔직하다': 149,
#  '크다': 150,
#  '우리': 151,
#  '추천': 152,
#  '눈물': 153,
#  '쓰다': 154,
#  '살다': 155,
#  '인지': 156,
#  '모든': 157,
#  '지만': 158,
#  '내다': 159,
#  '자체': 160,
#  '야하다': 161,
#  '허다': 162,
#  '찍다': 163,
#  '하지만': 164,
#  '인가': 165,
#  '캐릭터': 166,
#  '보이다': 167,
#  '코미디': 168,
#  '처럼': 169,
#  '대한': 170,
#  'ㅋㅋㅋㅋ': 171,
#  '모두': 172,
#  '이상': 173,
#  '뭔가': 174,
#  '돼다': 175,
#  '이네': 176,
#  '전혀': 177,
#  '대박': 178,
#  '이쁘다': 179,
#  '연기력': 180,
#  '건지다': 181,
#  '여운': 182,
#  '미치다': 183,
#  '그래도': 184,
#  '개봉': 185,
#  '공감': 186,
#  '짜증나다': 187,
#  '일본': 188,
#  '기대': 189,
#  '기대하다': 190,
#  '근데': 191,
#  '시리즈': 192,
#  '중간': 193,
#  '지다': 194,
#  '표현': 195,
#  '영상': 196,
#  '부분': 197,
#  '아주': 198,
#  '모습': 199,
#  '에는': 200,
#  '제목': 201,
#  '계속': 202,
#  '이랑': 203,
#  '치다': 204,
#  '이라': 205,
#  '귀엽다': 206,
#  '시키다': 207,
#  'ㅜㅜ': 208,
#  '가족': 209,
#  '내내': 210,
#  '믿다': 211,
#  '보지': 212,
#  '진심': 213,
#  '몰입': 214,
#  '밖에': 215,
#  '실망': 216,
#  '짜다': 217,
#  '기분': 218,
#  '대단하다': 219,
#  '작가': 220,
#  '떨어지다': 221,
#  '잔잔하다': 222,
#  '이제': 223,
#  '웃다': 224,
#  '요즘': 225,
#  '공포': 226,
#  '빠지다': 227,
#  '스릴러': 228,
#  '이라는': 229,
#  '긴장감': 230,
#  '개인': 231,
#  '조금': 232,
#  '애니': 233,
#  '대사': 234,
#  '이유': 235,
#  '알바': 236,
#  '특히': 237,
#  '제대로': 238,
#  '극장': 239,
#  '울다': 240,
#  '노래': 241,
#  '한테': 242,
#  '점도': 243,
#  '잇다': 244,
#  '점수': 245,
#  '시작': 246,
#  '막장': 247,
#  '이란': 248,
#  '나름': 249,
#  '오랜': 250,
#  '이상하다': 251,
#  '이지': 252,
#  '예쁘다': 253,
#  '깊다': 254,
#  '에도': 255,
#  '차라리': 256,
#  '제일': 257,
#  '노잼': 258,
#  '느껴지다': 259,
#  '친구': 260,
#  '해보다': 261,
#  '영화로': 262,
#  '당시': 263,
#  '같이': 264,
#  '어설프다': 265,
#  '의미': 266,
#  '빼다': 267,
#  '절대': 268,
#  '위해': 269,
#  '세상': 270,
#  '따뜻하다': 271,
#  '찾다': 272,
#  '아직도': 273,
#  '훌륭하다': 274,
#  '이라고': 275,
#  '년대': 276,
#  '공포영화': 277,
#  '미국': 278,
#  '웃음': 279,
#  '도대체': 280,
#  '생각나다': 281,
#  '설정': 282,
#  '아무': 283,
#  '무엇': 284,
#  '마다': 285,
#  '그리다': 286,
#  '죽이다': 287,
#  '초반': 288,
#  '써다': 289,
#  '다르다': 290,
#  '우리나라': 291,
#  '출연': 292,
#  '따다': 293,
#  '수작': 294,
#  '힘들다': 295,
#  '사실': 296,
#  '싫다': 297,
#  '답답하다': 298,
#  '엄청': 299,
#  '추억': 300,
#  '가지': 301,
#  '한국영': 302,
#  '놓다': 303,
#  '멋있다': 304,
#  '신선하다': 305,
#  '시나리오': 306,
#  '관객': 307,
#  '분위기': 308,
#  '아프다': 309,
#  '이야': 310,
#  '대다': 311,
#  '기다': 312,
#  '시대': 313,
#  '어이없다': 314,
#  '지루함': 315,
#  '필요없다': 316,
#  '장난': 317,
#  '잊다': 318,
#  '자신': 319,
#  '나쁘다': 320,
#  '소리': 321,
#  '이딴': 322,
#  '감정': 323,
#  '졸작': 324,
#  '엔딩': 325,
#  '이지만': 326,
#  '영화관': 327,
#  '엄마': 328,
#  '안타깝다': 329,
#  '오늘': 330,
#  '멀다': 331,
#  '결국': 332,
#  '정신': 333,
#  '제발': 334,
#  '인상': 335,
#  '부족하다': 336,
#  '배우다': 337,
#  '스럽다': 338,
#  '더빙': 339,
#  '포스터': 340,
#  '캐스팅': 341,
#  '라면': 342,
#  '평가': 343,
#  '더럽다': 344,
#  '코믹': 345,
#  '문제': 346,
#  '니까': 347,
#  '얼마나': 348,
#  '아무리': 349,
#  '최고다': 350,
#  '애니메이션': 351,
#  '함께': 352,
#  '어색하다': 353,
#  '그저': 354,
#  '몰입도': 355,
#  '서다': 356,
#  '낫다': 357,
#  '티비': 358,
#  '기도': 359,
#  '배경': 360,
#  '두다': 361,
#  '대해': 362,
#  '유쾌하다': 363,
#  '쓸다': 364,
#  '살리다': 365,
#  '비다': 366,
#  '망하다': 367,
#  '킬링타임': 368,
#  '나가다': 369,
#  '스릴': 370,
#  '충격': 371,
#  '전쟁': 372,
#  '만화': 373,
#  '얘기': 374,
#  '진부하다': 375,
#  '완벽하다': 376,
#  '존나': 377,
#  '적다': 378,
#  '건가': 379,
#  '예술': 380,
#  '개연': 381,
#  '그렇게': 382,
#  '머리': 383,
#  '갈수록': 384,
#  '매우': 385,
#  '놀라다': 386,
#  '즐겁다': 387,
#  '얼굴': 388,
#  '보단': 389,
#  '후회': 390,
#  '웃기': 391,
#  '이름': 392,
#  '읽다': 393,
#  '영화인': 394,
#  '옛날': 395,
#  '구성': 396,
#  '어디': 397,
#  '너무나': 398,
#  '어울리다': 399,
#  '행복하다': 400,
#  '집중': 401,
#  '이후': 402,
#  '들이다': 403,
#  '장르': 404,
#  '새롭다': 405,
#  '주연': 406,
#  '다큐': 407,
#  '시즌': 408,
#  '상황': 409,
#  '누구': 410,
#  '그래서': 411,
#  '이리': 412,
#  '억지': 413,
#  '언제': 414,
#  '짜증': 415,
#  '생기다': 416,
#  '예전': 417,
#  '충분하다': 418,
#  '아직': 419,
#  '후반': 420,
#  '다운': 421,
#  '역사': 422,
#  '어느': 423,
#  '강추': 424,
#  '궁금하다': 425,
#  '걸작': 426,
#  '여기': 427,
#  '불쌍하다': 428,
#  '누가': 429,
#  '밉다': 430,
#  '약간': 431,
#  '훨씬': 432,
#  '자기': 433,
#  '소름': 434,
#  '그것': 435,
#  '인물': 436,
#  '발연기': 437,
#  '그나마': 438,
#  '실화': 439,
#  '해도': 440,
#  '그대로': 441,
#  '방송': 442,
#  '심하다': 443,
#  '분들': 444,
#  '시절': 445,
#  '잔인하다': 446,
#  '비디오': 447,
#  '대체': 448,
#  '순수하다': 449,
#  '비슷하다': 450,
#  '만점': 451,
#  '그런': 452,
#  '소설': 453,
#  '한마디': 454,
#  '사회': 455,
#  '아들': 456,
#  '어렵다': 457,
#  '로맨스': 458,
#  '드리다': 459,
#  '비교': 460,
#  '초딩': 461,
#  '감성': 462,
#  '네이버': 463,
#  '필요하다': 464,
#  '쉬다': 465,
#  '따르다': 466,
#  '남기다': 467,
#  '다음': 468,
#  '만나다': 469,
#  '여주': 470,
#  '여배우': 471,
#  '전체': 472,
#  '간만': 473,
#  '타다': 474,
#  '떠나다': 475,
#  '상당하다': 476,
#  '라도': 477,
#  '편이': 478,
#  '나이': 479,
#  '만큼': 480,
#  '이라도': 481,
#  '당하다': 482,
#  '사랑스럽다': 483,
#  '나라': 484,
#  '굉장하다': 485,
#  '성룡': 486,
#  '동안': 487,
#  '이르다': 488,
#  '혼자': 489,
#  '터지다': 490,
#  '순간': 491,
#  '돌리다': 492,
#  '교훈': 493,
#  '삼류': 494,
#  '보다는': 495,
#  '빨리': 496,
#  '재밋': 497,
#  '감사하다': 498,
#  '그만': 499,
#  '존재': 500,
#  'ㅉㅉ': 501,
#  '바로': 502,
#  '풀다': 503,
#  '주제': 504,
#  '바라다': 505,
#  '진정하다': 506,
#  '목소리': 507,
#  '년도': 508,
#  '에요': 509,
#  '잡다': 510,
#  '망치다': 511,
#  '화려하다': 512,
#  '당신': 513,
#  '돋다': 514,
#  '거의': 515,
#  '지나다': 516,
#  '안보': 517,
#  '몇번': 518,
#  '낭비': 519,
#  '질질': 520,
#  '년전': 521,
#  '가볍다': 522,
#  '라니': 523,
#  '독특하다': 524,
#  '말고': 525,
#  '엄청나다': 526,
#  '줄거리': 527,
#  '맞추다': 528,
#  '성하다': 529,
#  '뜨다': 530,
#  '의도': 531,
#  '에선': 532,
#  '아버지': 533,
#  '좀비': 534,
#  '판타지': 535,
#  '이번': 536,
#  '담다': 537,
#  '갑자기': 538,
#  '그러나': 539,
#  '어른': 540,
#  '넣다': 541,
#  '전부': 542,
#  '상영': 543,
#  '점주': 544,
#  '시청률': 545,
#  '흥미롭다': 546,
#  '실제': 547,
#  'ㅎㅎㅎ': 548,
#  '넘치다': 549,
#  '힘드다': 550,
#  '평론가': 551,
#  '점점': 552,
#  '으로도': 553,
#  '만하': 554,
#  '기다리다': 555,
#  '한편': 556,
#  '그녀': 557,
#  '필요': 558,
#  '제작': 559,
#  '화면': 560,
#  '대로': 561,
#  '극장판': 562,
#  '만들어지다': 563,
#  '이기다': 564,
#  '중국': 565,
#  '각본': 566,
#  '에서도': 567,
#  '볼때': 568,
#  '간다': 569,
#  '억지스럽다': 570,
#  '달다': 571,
#  '바꾸다': 572,
#  '관람': 573,
#  '오글거리다': 574,
#  '저런': 575,
#  '스타일': 576,
#  '세계': 577,
#  '이하': 578,
#  '선택': 579,
#  '성우': 580,
#  '요소': 581,
#  '복수': 582,
#  '항상': 583,
#  '일단': 584,
#  '가치': 585,
#  '어디서': 586,
#  '굳다': 587,
#  '에서는': 588,
#  '갖다': 589,
#  '올리다': 590,
#  '흥행': 591,
#  '부르다': 592,
#  '참고': 593,
#  '그때': 594,
#  '가보다': 595,
#  '여러': 596,
#  '보내다': 597,
#  '더욱': 598,
#  '걸리다': 599,
#  '치고': 600,
#  '확실하다': 601,
#  '너무하다': 602,
#  '라서': 603,
#  '들어가다': 604,
#  '또한': 605,
#  '아빠': 606,
#  '물론': 607,
#  '역대': 608,
#  '평범하다': 609,
#  '거기': 610,
#  '수가': 611,
#  '불편하다': 612,
#  'ㅋㅋㅋㅋㅋ': 613,
#  '인거': 614,
#  '완성': 615,
#  '편집': 616,
#  '단순하다': 617,
#  '이냐': 618,
#  '상미': 619,
#  '멜로': 620,
#  '듣다': 621,
#  '끼다': 622,
#  '흐르다': 623,
#  '잃다': 624,
#  '전형': 625,
#  '짧다': 626,
#  '새끼': 627,
#  '허무하다': 628,
#  'ㅠㅠㅠ': 629,
#  '때리다': 630,
#  '걸다': 631,
#  '어이': 632,
#  '탄탄하다': 633,
#  '가지다': 634,
#  '화이팅': 635,
#  '진행': 636,
#  '개그': 637,
#  '에겐': 638,
#  '돋보이다': 639,
#  '엉망': 640,
#  '불륜': 641,
#  '거지': 642,
#  '예상': 643,
#  '이에요': 644,
#  '사건': 645,
#  '즐기다': 646,
#  '병맛': 647,
#  '중반': 648,
#  '미화': 649,
#  '지겹다': 650,
#  '그게': 651,
#  '똑같다': 652,
#  '소중하다': 653,
#  '어쩔': 654,
#  '설명': 655,
#  '과거': 656,
#  '메다': 657,
#  '찾아보다': 658,
#  '적당하다': 659,
#  '프랑스': 660,
#  '중요하다': 661,
#  '화보': 662,
#  '불다': 663,
#  '도저히': 664,
#  '노력': 665,
#  '훈훈하다': 666,
#  '댓글': 667,
#  '그래픽': 668,
#  '흥미': 669,
#  '닿다': 670,
#  '갈다': 671,
#  '흥미진진': 672,
#  '거리': 673,
#  '여서': 674,
#  '죽음': 675,
#  '꿀잼': 676,
#  '싸우다': 677,
#  '무조건': 678,
#  '원래': 679,
#  '취향': 680,
#  '식상하다': 681,
#  '화가': 682,
#  '뛰어나다': 683,
#  '마르다': 684,
#  '자극': 685,
#  '일이': 686,
#  '비추다': 687,
#  '감상': 688,
#  '역겹다': 689,
#  '만으로도': 690,
#  '만이': 691,
#  '한심하다': 692,
#  '학교': 693,
#  '길다': 694,
#  '자꾸': 695,
#  '액션영화': 696,
#  '뭐라다': 697,
#  '예고편': 698,
#  '오히려': 699,
#  '괜히': 700,
#  '결혼': 701,
#  '다가': 702,
#  '바보': 703,
#  '심리': 704,
#  '다루다': 705,
#  '이라니': 706,
#  '게임': 707,
#  '아저씨': 708,
#  '속편': 709,
#  '용도': 710,
#  '연기자': 711,
#  '보이': 712,
#  '잘만': 713,
#  '마무리': 714,
#  '나서다': 715,
#  '강하다': 716,
#  '관계': 717,
#  '나르다': 718,
#  '왠만하다': 719,
#  '천재': 720,
#  '미안하다': 721,
#  'ㄷㄷ': 722,
#  '억지로': 723,
#  '표정': 724,
#  '참신하다': 725,
#  '영환': 726,
#  '귀신': 727,
#  '최근': 728,
#  '한다는': 729,
#  '기억나다': 730,
#  '현재': 731,
#  '상상': 732,
#  '유치': 733,
#  '전설': 734,
#  '타임': 735,
#  '촬영': 736,
#  '오빠': 737,
#  '헐다': 738,
#  '아쉬움': 739,
#  '오래': 740,
#  '다니다': 741,
#  '대한민국': 742,
#  '조차': 743,
#  '빠져들다': 744,
#  '우연히': 745,
#  '흘리다': 746,
#  '전편': 747,
#  '스타': 748,
#  '잊혀지다': 749,
#  '묘사': 750,
#  '메세지': 751,
#  '진지하다': 752,
#  '만의': 753,
#  '대작': 754,
#  '철학': 755,
#  '겁나다': 756,
#  '프로그램': 757,
#  '동화': 758,
#  '프로': 759,
#  '돌아가다': 760,
#  '그림': 761,
#  '작다': 762,
#  '만에': 763,
#  '여전하다': 764,
#  '하하': 765,
#  '드럽다': 766,
#  '사라지다': 767,
#  '전달': 768,
#  '서로': 769,
#  '예요': 770,
#  '역할': 771,
#  '실망하다': 772,
#  '등장': 773,
#  '조연': 774,
#  '전작': 775,
#  '유머': 776,
#  '경찰': 777,
#  '졸라': 778,
#  '지루': 779,
#  '다행': 780,
#  '소녀': 781,
#  '이미': 782,
#  '먼저': 783,
#  '끌다': 784,
#  '나중': 785,
#  '무비': 786,
#  '살인': 787,
#  '마치': 788,
#  '멍청하다': 789,
#  '그런데': 790,
#  '덥다': 791,
#  '개다': 792,
#  '영원하다': 793,
#  '잘생기다': 794,
#  '흔하다': 795,
#  '살아가다': 796,
#  '겠다': 797,
#  '이며': 798,
#  '사이': 799,
#  '특유': 800,
#  '행동': 801,
#  '지난': 802,
#  '틀다': 803,
#  '약하다': 804,
#  '통해': 805,
#  '환상': 806,
#  '인정': 807,
#  '런가': 808,
#  '노출': 809,
#  '관심': 810,
#  '주의': 811,
#  '바뀌다': 812,
#  '쩔다': 813,
#  '청춘': 814,
#  '바람': 815,
#  '착하다': 816,
#  '예산': 817,
#  '군대': 818,
#  '리메이크': 819,
#  '안나': 820,
#  '묻다': 821,
#  '미래': 822,
#  '깊이': 823,
#  '스러운': 824,
#  '황당하다': 825,
#  '빌리다': 826,
#  '쏘다': 827,
#  '가능하다': 828,
#  '제작비': 829,
#  'ㅅㅂ': 830,
#  '깔다': 831,
#  '위대하다': 832,
#  '효과': 833,
#  '망작': 834,
#  '영웅': 835,
#  '왠지': 836,
#  '다만': 837,
#  '손발': 838,
#  '졸리다': 839,
#  '그닥': 840,
#  '너무나도': 841,
#  '용이': 842,
#  '케이블': 843,
#  '평생': 844,
#  '시도': 845,
#  '과정': 846,
#  '유명하다': 847,
#  '지나치다': 848,
#  '인하다': 849,
#  '얻다': 850,
#  '범인': 851,
#  '희망': 852,
#  '형님': 853,
#  '젊다': 854,
#  '채널': 855,
#  '능력': 856,
#  '반개': 857,
#  '미소': 858,
#  '태어나다': 859,
#  '잘못': 860,
#  '가끔': 861,
#  '상상력': 862,
#  '스케일': 863,
#  '참다': 864,
#  '다소': 865,
#  '신기하다': 866,
#  '카메라': 867,
#  '결론': 868,
#  '생애': 869,
#  '늙다': 870,
#  '광고': 871,
#  '설레다': 872,
#  '독립영화': 873,
#  '저렇게': 874,
#  '대충': 875,
#  '자막': 876,
#  '메시지': 877,
#  '안다': 878,
#  '던지다': 879,
#  '대안': 880,
#  '한계': 881,
#  '고민': 882,
#  '언니': 883,
#  '고맙다': 884,
#  '부족': 885,
#  '슬픔': 886,
#  '여성': 887,
#  '고생': 888,
#  '빠르다': 889,
#  '으로는': 890,
#  '사다': 891,
#  '원하다': 892,
#  '다시다': 893,
#  '리얼': 894,
#  '울리다': 895,
#  '졸다': 896,
#  '변하다': 897,
#  '커플': 898,
#  '산만하다': 899,
#  '찌다': 900,
#  '동생': 901,
#  '되게': 902,
#  '이면': 903,
#  '의리': 904,
#  '리뷰': 905,
#  '아침': 906,
#  '보시': 907,
#  '어린이': 908,
#  '추다': 909,
#  '시청자': 910,
#  '지키다': 911,
#  '괴물': 912,
#  '지르다': 913,
#  '자연': 914,
#  '희다': 915,
#  '살짝': 916,
#  '짱짱': 917,
#  '박수': 918,
#  '흐름': 919,
#  '로맨틱': 920,
#  '범죄': 921,
#  '굳이': 922,
#  '폭력': 923,
#  '연애': 924,
#  '개판': 925,
#  '로는': 926,
#  '표절': 927,
#  '포장': 928,
#  '챙기다': 929,
#  '정말로': 930,
#  '게이': 931,
#  '지도': 932,
#  'ㅇㅇ': 933,
#  '발견': 934,
#  '심심하다': 935,
#  '진정': 936,
#  '열심히': 937,
#  '기대다': 938,
#  '수도': 939,
#  '악역': 940,
#  '몸매': 941,
#  '어찌': 942,
#  '떠오르다': 943,
#  '덕분': 944,
#  '포기': 945,
#  '감탄': 946,
#  '진실': 947,
#  '일상': 948,
#  '어떤': 949,
#  '시선': 950,
#  '주기': 951,
#  '사극': 952,
#  '조폭': 953,
#  '혹시': 954,
#  '인기': 955,
#  '는걸': 956,
#  '문화': 957,
#  '쓰래': 958,
#  '정서': 959,
#  '성인': 960,
#  '우정': 961,
#  '대의': 962,
#  '남녀': 963,
#  '상처': 964,
#  '끝내다': 965,
#  '더하다': 966,
#  '과연': 967,
#  '눈물나다': 968,
#  '깔끔하다': 969,
#  '퀄리티': 970,
#  '이래': 971,
#  '우울하다': 972,
#  '로서': 973,
#  '유일하다': 974,
#  '벗다': 975,
#  '홍콩': 976,
#  '성도': 977,
#  '용서': 978,
#  '접다': 979,
#  '특별하다': 980,
#  '끼리': 981,
#  '스럽게': 982,
#  '이연걸': 983,
#  '와는': 984,
#  '쩐다': 985,
#  '일어나다': 986,
#  '오락': 987,
#  '막판': 988,
#  '하루': 989,
#  '뛰다': 990,
#  '코드': 991,
#  '홍보': 992,
#  '크게': 993,
#  '볼거리': 994,
#  '섹스': 995,
#  '말로': 996,
#  '뮤지컬': 997,
#  '짓다': 998,
#  '국민': 999,
#  '정치': 1000,
#  ...}

# %%
# 단어 등장 수
tokenizer.word_counts
# Out:
# OrderedDict([('더빙', 572),
#              ('진짜', 8288),
#              ('짜증나다', 1002),
#              ('목소리', 374),
#              ('포스터', 572),
#              ('보고', 4653),
#              ('초딩', 422),
#              ('영화', 50172),
#              ('오버', 142),
#              ('연기', 6326),
#              ('조차', 242),
#              ('가볍다', 360),
#              ('않다', 7718),
#              ('무재', 69),
#              ('밓었', 1),
#              ('다그', 75),
#              ('래서', 20),
#              ('보다', 40991),
#              ('추천', 1180),
#              ('교도소', 16),
#              ('이야기', 2171),
#              ('구먼', 11),
#              ('솔직하다', 1199),
#              ('재미', 3854),
#              ('없다', 15519),
#              ('평점', 6245),
#              ('조정', 40),
#              ('사이', 222),
#              ('몬페', 2),
#              ('익살스럽다', 9),
#              ('돋보이다', 288),
#              ('스파이더맨', 64),
#              ('에서', 6979),
#              ('늙다', 198),
#              ('보이다', 1073),
#              ('하다', 40759),
#              ('커스틴', 4),
#              ('던스트', 2),
#              ('너무나도', 206),
#              ('이쁘다', 1033),
#              ('걸음', 20),
#              ('떼다', 151),
#              ('부터', 1717),
#              ('초등학교', 116),
#              ('학년', 121),
#              ('생인', 6),
#              ('살다', 1173),
#              ('ㅋㅋㅋ', 2448),
#              ('반개', 202),
#              ('아깝다', 4373),
#              ('원작', 1253),
#              ('긴장감', 832),
#              ('제대로', 796),
#              ('살리다', 532),
#              ('나오다', 6394),
#              ('이응경', 8),
#              ('길용우', 4),
#              ('생활', 126),
#              ('인지', 1170),
#              ('정말', 9662),
#              ('해도', 440),
#              ('그것', 444),
#              ('보단', 508),
#              ('낫다', 543),
#              ('납치', 49),
#              ('감금', 11),
#              ('반복', 151),
#              ('드라마', 5024),
#              ('가족', 937),
#              ('사람', 4836),
#              ('액션', 2394),
#              ('있다', 12424),
#              ('안되다', 2320),
#              ('왜케', 131),
#              ('낮다', 1309),
#              ('헐리우드', 143),
#              ('화려하다', 368),
#              ('너무', 11069),
#              ('길들이다', 20),
#              ('인피니트', 27),
#              ('이다', 13140),
#              ('볼때', 324),
#              ('마다', 675),
#              ('눈물나다', 174),
#              ('죽다', 1295),
#              ('년대', 687),
#              ('향수', 66),
#              ('허진호', 6),
#              ('감성', 420),
#              ('절제', 67),
#              ('멜로', 297),
#              ('달인', 21),
#              ('울면', 78),
#              ('횡단보도', 1),
#              ('건너다', 8),
#              ('뛰다', 171),
#              ('치다', 948),
#              ('이범수', 39),
#              ('드럽다', 233),
#              ('담백하다', 68),
#              ('깔끔하다', 174),
#              ('좋다', 11911),
#              ('로만', 139),
#              ('자꾸', 263),
#              ('잊어버리다', 15),
#              ('취향', 273),
#              ('존중', 36),
#              ('다지', 18),
#              ('내생', 106),
#              ('극장', 794),
#              ('가장', 1385),
#              ('노잼', 737),
#              ('감동', 4803),
#              ('스토리', 5329),
#              ('어거지', 76),
#              ('매번', 65),
#              ('긴장', 153),
#              ('되다', 8843),
#              ('재밋음', 81),
#              ('ㅠㅠ', 2473),
#              ('차다', 2301),
#              ('웃기다', 1368),
#              ('바스코', 15),
#              ('이기', 168),
#              ('락스', 13),
#              ('라고', 1778),
#              ('끄다', 1490),
#              ('바비', 24),
#              ('아이돌', 148),
#              ('이라고', 689),
#              ('깔다', 211),
#              ('안달', 22),
#              ('처럼', 1065),
#              ('굿바이', 21),
#              ('레닌', 6),
#              ('표절', 182),
#              ('이해', 1893),
#              ('갈수록', 512),
#              ('없어지다', 135),
#              ('이건', 2566),
#              ('깨알', 68),
#              ('캐스팅', 572),
#              ('질퍽', 3),
#              ('산뜻하다', 14),
#              ('용구성', 6),
#              ('자다', 3609),
#              ('버무러진', 2),
#              ('일드', 37),
#              ('약탈', 4),
#              ('변명', 29),
#              ('이르다', 392),
#              ('착하다', 217),
#              ('절대', 714),
#              ('아니다', 7738),
#              ('나름', 760),
#              ('심오하다', 100),
#              ('그냥', 4049),
#              ('학생', 133),
#              ('선생', 64),
#              ('놀다', 106),
#              ('웃다', 854),
#              ('불가능하다', 48),
#              ('재미없다', 3416),
#              ('지루하다', 3479),
#              ('같다', 8341),
#              ('음식', 82),
#              ('인데', 2060),
#              ('바베트', 1),
#              ('만찬', 9),
#              ('하고', 3563),
#              ('넘다', 2108),
#              ('차이', 161),
#              ('남바', 1),
#              ('베트', 3),
#              ('별로', 1947),
#              ('핀란드', 8),
#              ('풍경', 120),
#              ('이라도', 400),
#              ('할랫', 1),
#              ('늘다', 1222),
#              ('ㅡㅡ', 2061),
#              ('평범하다', 300),
#              ('수작', 639),
#              ('이라', 947),
#              ('는걸', 176),
#              ('말씀드리다', 6),
#              ('주제', 378),
#              ('중반', 285),
#              ('짤랐을꺼', 1),
#              ('그래서', 473),
#              ('납득', 55),
#              ('그렇다', 3093),
#              ('고추', 15),
#              ('털다', 27),
#              ('버리다', 1770),
#              ('카밀라', 10),
#              ('발연기', 441),
#              ('재밋는뎅', 1),
#              ('센스', 81),
#              ('연출', 2075),
#              ('탁월하다', 66),
#              ('엄포스', 3),
#              ('위력', 12),
#              ('다시', 2806),
#              ('한번', 1405),
#              ('깨닫다', 148),
#              ('해주다', 1644),
#              ('적남', 1),
#              ('검사', 55),
#              ('완전', 2507),
#              ('명품', 136),
#              ('쓰레기', 3391),
#              ('진부하다', 518),
#              ('도안', 131),
#              ('돼다', 1041),
#              ('ㅋㅋ', 4272),
#              ('아시', 42),
#              ('재밌다', 8652),
#              ('이리', 469),
#              ('라도', 406),
#              ('기대하다', 996),
#              ('죄인', 13),
#              ('아직도', 695),
#              ('인생', 1496),
#              ('최고', 5681),
#              ('패션', 38),
#              ('대한', 1055),
#              ('열정', 159),
#              ('안나', 216),
#              ('투어', 7),
#              ('키이라', 16),
#              ('나이틀리', 8),
#              ('대체', 431),
#              ('정신장애', 2),
#              ('틱장애', 3),
#              ('허허', 85),
#              ('작가', 879),
#              ('정신', 579),
#              ('나가다', 524),
#              ('유령', 49),
#              ('재미있다', 3951),
#              ('관객', 617),
#              ('이네', 1039),
#              ('이렇게', 2325),
#              ('평가', 569),
#              ('받다', 1983),
#              ('모르다', 3208),
#              ('단순하다', 298),
#              ('은은하다', 35),
#              ('매력', 1364),
#              ('알바생', 53),
#              ('인가', 1081),
#              ('내용', 3811),
#              ('무섭다', 1416),
#              ('하나', 2810),
#              ('싱겁다', 55),
#              ('ㅇㅇ', 181),
#              ('시간', 3852),
#              ('낚임', 26),
#              ('오다', 2508),
#              ('두다', 534),
#              ('서리', 11),
#              ('굶주리다', 4),
#              ('들다', 3196),
#              ('방법', 141),
#              ('ㅜㅡ', 17),
#              ('윤제문', 13),
#              ('이라는', 843),
#              ('멋지다', 1254),
#              ('배우', 4282),
#              ('발견', 181),
#              ('소소하다', 144),
#              ('잔잔하다', 874),
#              ('미소', 202),
#              ('머금', 8),
#              ('음악', 1276),
#              ('조금', 806),
#              ('아쉽다', 1523),
#              ('주다', 3720),
#              ('싶다', 3051),
#              ('올리다', 311),
#              ('속지', 66),
#              ('말다', 1309),
#              ('낭비', 362),
#              ('리얼리티', 72),
#              ('뛰어나다', 271),
#              ('한데', 123),
#              ('크다', 1193),
#              ('공감', 1003),
#              ('간다', 324),
#              ('이민기', 44),
#              ('캐릭터', 1075),
#              ('정신의학', 1),
#              ('분노조절', 5),
#              ('장애', 54),
#              ('초기', 42),
#              ('증상', 3),
#              ('툭하면', 13),
#              ('물건', 38),
#              ('파손', 2),
#              ('초반', 663),
#              ('신선하다', 619),
#              ('가면', 155),
#              ('상태', 105),
#              ('불가', 163),
#              ('마이너스', 122),
#              ('뮤비', 18),
#              ('수준', 1445),
#              ('ㅉㅉ', 381),
#              ('북한', 166),
#              ('이렇다', 4583),
#              ('만들다', 6500),
#              ('대다', 612),
#              ('우리', 1187),
#              ('사랑', 2939),
#              ('리스', 34),
#              ('타르', 8),
#              ('가르다', 39),
#              ('엔나', 1),
#              ('용의', 24),
#              ('주인', 46),
#              ('이랑', 952),
#              ('근친상간', 10),
#              ('이나', 1762),
#              ('다니다', 243),
#              ('소설', 426),
#              ('에선', 353),
#              ('제일', 743),
#              ('니스', 14),
#              ('드래곤', 24),
#              ('용이', 206),
#              ('웃음', 683),
#              ('감독', 4113),
#              ('토르', 27),
#              ('다크', 39),
#              ('월드', 41),
#              ('잡수다', 6),
#              ('기본', 158),
#              ('선방', 4),
#              ('영혼', 122),
#              ('어루만지다', 12),
#              ('수도', 180),
#              ('거치다', 76),
#              ('상사', 18),
#              ('잠시', 88),
#              ('잊다', 598),
#              ('동화', 236),
#              ('행복하다', 500),
#              ('세르게이', 6),
#              ('작다', 235),
#              ('맵다', 7),
#              ('보여주다', 1467),
#              ('포퐁', 1),
#              ('저그', 20),
#              ('진호', 9),
#              ('가슴', 1325),
#              ('시리', 14),
#              ('자체', 1146),
#              ('난또', 6),
#              ('꼬마', 103),
#              ('애가', 96),
#              ('무슨', 1596),
#              ('원한', 22),
#              ('깊다', 749),
#              ('혼자', 392),
#              ('나대다', 24),
#              ('어쩌라고', 34),
#              ('충격', 523),
#              ('적다', 516),
#              ('기분', 887),
#              ('완전하다', 149),
#              ('꺼지다', 71),
#              ('느낌', 2093),
#              ('이라고는', 31),
#              ('무겁다', 163),
#              ('지독하다', 51),
#              ('차갑다', 72),
#              ('무자비하다', 12),
#              ('그저', 549),
#              ('일본인', 80),
#              ('상상력', 201),
#              ('대단하다', 886),
#              ('생각', 5312),
#              ('심심하다', 181),
#              ('백봉기', 1),
#              ('언제', 465),
#              ('그대로', 439),
#              ('들어맞다', 15),
#              ('예측', 62),
#              ('카리스마', 122),
#              ('악역', 180),
#              ('불알', 3),
#              ('당황', 90),
#              ('아무튼', 80),
#              ('중간', 992),
#              ('끝나다', 1331),
#              ('녹다', 78),
#              ('일상', 178),
#              ('밋밋하다', 128),
#              ('계속', 954),
#              ('전개도', 137),
#              ('느리다', 154),
#              ('주인공', 2375),
#              ('은희', 26),
#              ('한두', 33),
#              ('극적', 60),
#              ('모습', 973),
#              ('짜증', 464),
#              ('ㅜㅜ', 945),
#              ('맨날', 146),
#              ('대만', 34),
#              ('전개', 1359),
#              ('빨리', 385),
#              ('가슴속', 34),
#              ('감정', 594),
#              ('헤집다', 5),
#              ('예요', 231),
#              ('많다', 2460),
#              ('다큐', 475),
#              ('우리나라', 647),
#              ('슬프다', 1290),
#              ('현대', 86),
#              ('사의', 29),
#              ('단면', 14),
#              ('대해', 534),
#              ('깊이', 215),
#              ('사죄', 7),
#              ('바로', 379),
#              ('잡기', 18),
#              ('위해', 706),
#              ('노력', 277),
#              ('말로', 169),
#              ('듣다', 297),
#              ('보도', 11),
#              ('연맹', 1),
#              ('민간인', 22),
#              ('학살', 46),
#              ('이정', 128),
#              ('이야', 613),
#              ('명백하다', 20),
#              ('살인', 227),
#              ('살인자', 51),
#              ('어디', 503),
#              ('예전', 463),
#              ('작품', 2975),
#              ('에피소드', 131),
#              ('재탕', 36),
#              ('사골', 21),
#              ('우려', 105),
#              ('먹듯', 10),
#              ('으로', 7930),
#              ('가다', 3208),
#              ('시청률', 344),
#              ('아예', 107),
#              ('이제', 866),
#              ('부작', 81),
#              ('이라니', 258),
#              ('김남길', 30),
#              ('짜다', 892),
#              ('연기력', 1030),
#              ('몰입도', 548),
#              ('에도', 747),
#              ('불구', 156),
#              ('손예진', 50),
#              ('ㅈㅈ', 3),
#              ('비슷하다', 429),
#              ('한테', 788),
#              ('노래실력', 5),
#              ('뽑다', 135),
#              ('맞다', 1413),
#              ('박시환', 17),
#              ('망신', 26),
#              ('일본', 999),
#              ('이런', 1848),
#              ('건가', 515),
#              ('유치하다', 1275),
#              ('이틀', 25),
#              ('만에', 234),
#              ('근데', 993),
#              ('넣다', 349),
#              ('조작', 107),
#              ('안이', 17),
#              ('열리다', 48),
#              ('활짝', 9),
#              ('아무나', 56),
#              ('들어가다', 302),
#              ('문자', 16),
#              ('비번', 3),
#              ('걸리다', 308),
#              ('억지스럽다', 324),
#              ('그래도', 1015),
#              ('졸작', 590),
#              ('재밋네', 38),
#              ('달팽이', 8),
#              ('라서', 304),
#              ('어설프다', 722),
#              ('어이없다', 600),
#              ('결말', 1577),
#              ('부패하다', 7),
#              ('로마노프', 2),
#              ('왕조', 2),
#              ('기리', 34),
#              ('뭣같', 6),
#              ('온몸', 36),
#              ('항거', 3),
#              ('러시아', 72),
#              ('민중', 13),
#              ('폭도', 8),
#              ('무난', 69),
#              ('펴다', 81),
#              ('매우', 512),
#              ('실망', 901),
#              ('한국영', 624),
#              ('흥행', 311),
#              ('코드', 171),
#              ('갈등', 138),
#              ('화해', 34),
#              ('남발', 40),
#              ('뻔하다', 1498),
#              ('아햏햏', 4),
#              ('시작', 771),
#              ('분만', 99),
#              ('리플릿', 1),
#              ('사진', 110),
#              ('불안하다', 45),
#              ('단연', 129),
#              ('먹다', 1684),
#              ('에게', 1592),
#              ('엉망', 288),
#              ('진창', 50),
#              ('우뢰매', 82),
#              ('진정', 181),
#              ('위대하다', 211),
#              ('별루', 104),
#              ('내일', 76),
#              ('기대', 999),
#              ('조미', 11),
#              ('막문위', 2),
#              ('좋아하다', 2010),
#              ('가요', 134),
#              ('골깜', 1),
#              ('부라리다', 2),
#              ('쓰러지다', 40),
#              ('성룡', 394),
#              ('최악', 2166),
#              ('때리다', 293),
#              ('ㅋㅋㅋㅋ', 1055),
#              ('걸스데이', 3),
#              ('이혜리', 1),
#              ('서기', 34),
#              ('ㅋㅋㅋㅋㅋ', 299),
#              ('인공', 30),
#              ('주귀', 1),
#              ('ㅋㅋㅋㅋㅋㅋ', 140),
#              ('인상', 577),
#              ('어내스트', 1),
#              ('셀레스틴', 2),
#              ('강추', 456),
#              ('에요', 372),
#              ('클라라', 54),
#              ('볼라', 52),
#              ('화신', 24),
#              ('설정', 679),
#              ('새롭다', 481),
#              ('메인', 41),
#              ('차차', 4),
#              ('신카이', 4),
#              ('마코토', 5),
#              ('작화', 57),
#              ('밉다', 452),
#              ('카나', 3),
#              ('대박', 1034),
#              ('진심', 909),
#              ('이훨', 1),
#              ('인거', 299),
#              ('고은님', 1),
#              ('쓰다', 1175),
#              ('노골', 42),
#              ('광고', 198),
#              ('어떻다', 1463),
#              ('킬링타임', 526),
#              ('크리스마스', 114),
#              ('떠오르다', 179),
#              ('행복', 159),
#              ('ㅎㅎㅎ', 343),
#              ('빠지다', 847),
#              ('산만하다', 189),
#              ('태어나다', 202),
#              ('처음', 2451),
#              ('불륜', 288),
#              ('로맨스', 423),
#              ('아주', 979),
#              ('짬뽕', 64),
#              ('믹스', 15),
#              ('음향', 48),
#              ('별루더', 1),
#              ('기준', 118),
#              ('패널', 8),
#              ('가구', 7),
#              ('명작', 2007),
#              ('망치', 56),
#              ('서운하다', 7),
#              ('이상하다', 754),
#              ('몬스터', 31),
#              ('주식회사', 7),
#              ('너무나', 503),
#              ('소재', 1508),
#              ('흥미', 275),
#              ('지만', 1160),
#              ('박하다', 56),
#              ('몰입', 907),
#              ('중국인', 38),
#              ('특유', 222),
#              ('과장', 138),
#              ('허풍', 8),
#              ('안간힘', 4),
#              ('쓸다', 533),
#              ('가상하다', 24),
#              ('고증', 59),
#              ('실감', 159),
#              ('떨어지다', 877),
#              ('거북', 17),
#              ('스럽다', 574),
#              ('도대체', 682),
#              ('까지', 3777),
#              ('스스로', 138),
#              ('과대', 65),
#              ('포장', 182),
#              ('불법체류자', 14),
#              ('잡다', 370),
#              ('우상화', 4),
#              ('미국', 686),
#              ('따뜻하다', 700),
#              ('뭥미', 87),
#              ('삶속', 7),
#              ('생애', 199),
#              ('전부', 347),
#              ('드러나다', 84),
#              ('점점', 338),
#              ('지난', 221),
#              ('남다', 1923),
#              ('지나', 67),
#              ('순수하다', 430),
#              ('숀펜', 21),
#              ('또한', 302),
#              ('올레', 62),
#              ('공짜', 114),
#              ('헐다', 244),
#              ('문제', 567),
#              ('연기자', 255),
#              ('전혀', 1038),
#              ('배역', 111),
#              ('어울리다', 503),
#              ('그리고', 2004),
#              ('상대', 63),
#              ('따로', 114),
#              ('놓다', 620),
#              ('보아', 166),
#              ('라미란', 5),
#              ('아들', 424),
#              ('욕심', 94),
#              ('어느', 458),
#              ('만이라도', 16),
#              ('빵점', 106),
#              ('베댓', 14),
#              ('잘쓰다', 30),
#              ('모자라다', 108),
#              ('도둑', 64),
#              ('뫼비우스', 5),
#              ('나라', 398),
#              ('만들어지다', 330),
#              ('믿어지다', 16),
#              ('찌릿짜릿', 1),
#              ('용기', 103),
#              ('교훈', 388),
#              ('화이', 24),
#              ('당시', 729),
#              ('상황', 474),
#              ('주입', 13),
#              ('식이', 57),
#              ('전하', 71),
#              ('케이블', 206),
#              ('그만', 383),
#              ('다르다', 655),
#              ('이냐', 298),
#              ('리투', 1),
#              ('차이밍량', 1),
#              ('섞이다', 70),
#              ('그릇', 22),
#              ('담기다', 154),
#              ('여군', 25),
#              ('건지다', 1028),
#              ('엠비씨', 26),
#              ('질린다', 30),
#              ('한석규', 57),
#              ('김혜수', 57),
#              ('어딘', 6),
#              ('많이', 1929),
#              ('에볼라', 4),
#              ('바이러스', 30),
#              ('떠들다', 53),
#              ('어떤', 178),
#              ('에서도', 325),
#              ('년전', 361),
#              ('보기', 1611),
#              ('믿다', 922),
#              ('힘들다', 636),
#              ('정도', 2585),
#              ('마지막', 2756),
#              ('후반', 460),
#              ('부가', 37),
#              ('살짝', 184),
#              ('하지만', 1105),
#              ('만해', 119),
#              ('떨다', 85),
#              ('용가리', 35),
#              ('짱짱맨', 55),
#              ('서다', 547),
#              ('감히', 119),
#              ('하나로', 116),
#              ('야하다', 1140),
#              ('나르다', 252),
#              ('고민', 194),
#              ('모건', 24),
#              ('프리', 43),
#              ('멀다', 583),
#              ('나이', 401),
#              ('여전하다', 234),
#              ('섹시하다', 129),
#              ('재방송', 46),
#              ('시나', 13),
#              ('여운', 1022),
#              ('왠만하다', 252),
#              ('상업', 124),
#              ('퀄리티', 174),
#              ('쩔다', 219),
#              ('충분하다', 462),
#              ('개인', 828),
#              ('잔인하다', 435),
#              ('자극', 270),
#              ('노출씬', 11),
#              ('화끈하다', 107),
#              ('국산', 58),
#              ('아끼다', 84),
#              ('보임', 66),
#              ('끝내', 72),
#              ('지겹다', 284),
#              ('역시', 1979),
#              ('드니', 66),
#              ('일품', 116),
#              ('나다', 2242),
#              ('맥스', 41),
#              ('죽이다', 666),
#              ('바랬다', 6),
#              ('괜찮다', 1780),
#              ('스러웟음', 1),
#              ('지네', 43),
#              ('뜨다', 354),
#              ('찍을껀데', 1),
#              ('면상', 16),
#              ('알다', 2938),
#              ('자신', 597),
#              ('어린이', 186),
#              ('어리다', 1442),
#              ('동심', 74),
#              ('멀리', 45),
#              ('무술', 113),
#              ('총을드', 1),
#              ('크리스토퍼', 31),
#              ('왈츠', 11),
#              ('타란티노', 67),
#              ('조합', 131),
#              ('이란', 761),
#              ('한국', 1333),
#              ('유명', 33),
#              ('한편', 333),
#              ('외국', 145),
#              ('상상', 247),
#              ('초월', 61),
#              ('유명하다', 205),
#              ('오랜', 759),
#              ('재밋', 384),
#              ('종방', 6),
#              ('되어다', 1363),
#              ('오늘', 584),
#              ('방도', 13),
#              ('방송', 439),
#              ('대본', 98),
#              ('완성', 299),
#              ('요즘', 852),
#              ('막장', 766),
#              ('지치다', 86),
#              ('수백향', 8),
#              ('바른', 6),
#              ('그리다', 675),
#              ('심하다', 438),
#              ('화이팅', 289),
#              ('조절', 113),
#              ('위원회', 29),
#              ('김혜선', 12),
#              ('순정', 23),
#              ('정이', 87),
#              ('역할', 231),
#              ('팜므파탈', 7),
#              ('로써', 125),
#              ('해내다', 152),
#              ('의외', 60),
#              ('사극', 177),
#              ('벌어지다', 59),
#              ('그녀', 333),
#              ('논란', 26),
#              ('왠지', 209),
#              ('코미디', 1069),
#              ('장면', 2425),
#              ('멍하다', 37),
#              ('한마디', 425),
#              ('공유', 64),
#              ('존잘', 20),
#              ('상쾌', 18),
#              ('발랄하다', 52),
#              ('껄끄런', 1),
#              ('유쾌하다', 534),
#              ('해설', 26),
#              ('소파', 7),
#              ('치고', 308),
#              ('앉다', 107),
#              ('지키다', 185),
#              ('이유', 798),
#              ('로큰롤', 3),
#              ('주된', 14),
#              ('타겟', 14),
#              ('일반', 71),
#              ('논리', 86),
#              ('게임', 258),
#              ('흥미롭다', 344),
#              ('요원', 26),
#              ('무능력하다', 15),
#              ('배경', 536),
#              ('거슬리다', 120),
#              ('뮤지컬', 169),
#              ('사운드', 83),
#              ('녹음', 21),
#              ('추다', 186),
#              ('어제', 168),
#              ('참다', 200),
#              ('말리', 25),
#              ('영국', 110),
#              ('예산', 217),
#              ('뮤지컬영화', 14),
#              ('맘마미아', 9),
#              ('로맨틱코미디', 58),
#              ('게이물', 8),
#              ('알바', 797),
#              ('알고싶다', 22),
#              ('스텝', 58),
#              ('꼭두각시', 11),
#              ('아름답다', 1647),
#              ('익숙해지다', 17),
#              ('현대인', 31),
#              ('힘드다', 340),
#              ('뻑뻑', 2),
#              ('읽다', 505),
#              ('볼걸', 44),
#              ('당하다', 399),
#              ('극치', 130),
#              ('굉장하다', 395),
#              ('언밸러스', 1),
#              ('뚱뚱하다', 11),
#              ('생기다', 464),
#              ('남자', 1332),
#              ('시종일관', 58),
#              ('고역', 8),
#              ('간간히', 44),
#              ('흘러나오다', 30),
#              ('클래식', 60),
#              ('조차도', 45),
#              ('듣기', 68),
#              ('싫다', 634),
#              ('상당하다', 408),
#              ('주기도', 142),
#              ('얼마나', 566),
#              ('밖에', 902),
#              ('인가요', 133),
#              ('죄송하다', 56),
#              ('화가', 272),
#              ('나서다', 254),
#              ('아무', 679),
#              ('보지', 922),
#              ('티비', 542),
#              ('짜지다', 100),
#              ('돼지', 85),
#              ('닭목', 2),
#              ('따다', 641),
#              ('우웩', 14),
#              ('무당', 14),
#              ('판타지', 352),
#              ('가져가다', 15),
#              ('윤종신', 4),
#              ('복귀', 22),
#              ('이하늘', 2),
#              ('뽑히다', 14),
#              ('참가자', 14),
#              ('실력', 153),
#              ('심사', 56),
#              ('위원', 37),
#              ('인격', 17),
#              ('쌓다', 21),
#              ('어허', 5),
#              ('광장', 7),
#              ('옛날', 504),
#              ('어린시절', 110),
#              ('추억', 630),
#              ('판타지영화', 26),
#              ('나쁘다', 597),
#              ('짓다', 169),
#              ('금물', 13),
#              ('지옥', 63),
#              ('기존', 77),
#              ('멜로영화', 60),
#              ('형식', 56),
#              ('탈피', 8),
#              ('지나치다', 205),
#              ('사랑비', 2),
#              ('서준', 1),
#              ('후회', 506),
#              ('이영화', 1815),
#              ('니까', 567),
#              ('주네', 46),
#              ('젖다', 40),
#              ('없이', 1453),
#              ('보고오다', 105),
#              ('싸이코', 120),
#              ('벗어나다', 111),
#              ('년도', 373),
#              ('개봉', 1010),
#              ('허다', 1129),
#              ('접해', 5),
#              ('사랑스럽다', 399),
#              ('귀엽다', 947),
#              ('청춘', 218),
#              ('만이', 265),
#              ('넘치다', 342),
#              ('순간', 389),
#              ('지나가다', 101),
#              ('돌아오다', 134),
#              ('만큼은', 120),
#              ('무한', 71),
#              ('젊음', 40),
#              ('건담', 23),
#              ('시리즈', 993),
#              ('아직', 461),
#              ('까지도', 153),
#              ('최고봉', 77),
#              ('개콘', 69),
#              ('코너', 21),
#              ('이고', 1604),
#              ('이안', 61),
#              ('사다코', 33),
#              ('서린', 9),
#              ('우물', 16),
#              ('펀치', 15),
#              ('후세', 10),
#              ('결정', 111),
#              ('계기', 69),
#              ('표현', 990),
#              ('생명', 60),
#              ('빼앗다', 13),
#              ('출현', 47),
#              ('연극', 82),
#              ('이든', 141),
#              ('본능', 66),
#              ('면서', 121),
#              ('새벽', 143),
#              ('이래', 174),
#              ('강수연', 17),
#              ('최정원', 4),
#              ('신음', 13),
#              ('김혜성', 3),
#              ('예쁘다', 750),
#              ('이현진', 1),
#              ('가발', 15),
#              ('여정', 36),
#              ('이인상', 3),
#              ('재밋어', 101),
#              ('배두나', 25),
#              ('대들다', 15),
#              ('성적', 72),
#              ('호기심', 69),
#              ('필요', 333),
#              ('닥치고', 56),
#              ('각기', 5),
#              ('다른', 1269),
#              ('미국드라마', 3),
#              ('파워', 49),
#              ('미묘하다', 38),
#              ('사로자다', 28),
#              ('훈훈하다', 276),
#              ('응답', 8),
#              ('하라', 69),
#              ('은지원', 14),
#              ...])

# %%
# 총 단어 등장 수 
total_cnt = len(tokenizer.word_index)
total_cnt
# Out:
# 42120

# %%
# 사용 단어 수를 지정하여 토큰화
tokenizer = Tokenizer(num_words = 1000)
tokenizer.fit_on_texts(train_df["token"])

# %%
x_train = tokenizer.texts_to_sequences(train_df["token"])
x_test= tokenizer.texts_to_sequences(test_df["token"])

# %%
x_train
# Out:
# [[339, 13, 187, 507],
#  [340, 28, 461, 1, 20, 743, 522, 16],
#  [2, 152],
#  [72, 149, 36, 4, 21],
#  [799, 20, 639, 1, 17, 870, 167, 3, 841, 179, 167],
#  [98, 155, 1, 64, 857, 30],
#  [146, 230, 238, 365, 3],
#  [857, 30, 19, 156, 9, 440, 435, 389, 357, 25, 209, 4, 20, 3, 26],
#  [66, 4, 36, 6, 69, 1],
#  [21, 136, 512, 8, 6],
#  [5, 13, 5],
#  [568, 285, 968, 139, 276, 462, 620, 5],
#  [990, 204, 20, 766, 3],
#  [969, 7, 2, 2, 695, 26, 5],
#  [680, 13, 239, 17, 2, 1, 124, 258, 27, 23, 27],
#  [10, 61],
#  [70, 26, 125, 93, 114, 275, 831, 114, 169, 167],
#  [927, 88, 3, 384, 36],
#  [58, 9, 341, 16, 41],
#  [488, 816, 268, 15],
#  [249, 6, 34, 1, 268, 15],
#  [2, 224, 16],
#  [44,
#   43,
#   12,
#   1,
#   79,
#   42,
#   75,
#   72,
#   6,
#   2,
#   36,
#   6,
#   58,
#   4,
#   85,
#   19,
#   481,
#   147,
#   435,
#   85,
#   19,
#   78],
#  [268, 609, 1, 15, 294, 205, 956],
#  [504, 7, 648, 98, 43],
#  [411, 3, 4, 49, 49, 114],
#  [94, 3],
#  [437],
#  [],
#  [6, 77, 341, 276, 411],
#  [55, 123, 101, 20, 9, 7, 60, 25],
#  [45, 375, 175, 32, 30],
#  [11, 412, 136],
#  [477, 190, 5, 5],
#  [273, 25, 113, 22],
#  [170, 820],
#  [20, 3, 3, 448, 5, 5],
#  [220, 333, 369, 205, 35],
#  [340, 6, 167, 307, 176],
#  [1, 68, 343, 83, 46],
#  [617, 127, 1],
#  [165, 38, 4, 120, 4, 125, 54, 4, 60, 1, 933, 37, 75, 30, 60],
#  [59, 361],
#  [9, 48, 411, 2, 2, 4],
#  [229,
#   145,
#   31,
#   934,
#   3,
#   175,
#   222,
#   858,
#   3,
#   141,
#   232,
#   109,
#   61,
#   40,
#   50,
#   21,
#   590,
#   50,
#   40],
#  [21, 137, 37, 519, 519],
#  [683, 150, 186, 569, 166, 5, 26, 42, 42, 232, 5, 288, 305, 384, 333, 186],
#  [4, 28, 1, 118, 3, 501, 17, 29, 18, 311],
#  [151, 1, 52, 3],
#  [10,
#   50,
#   203,
#   95,
#   3,
#   741,
#   453,
#   532,
#   257,
#   145,
#   5,
#   25,
#   532,
#   842,
#   257,
#   145,
#   279,
#   33,
#   3],
#  [1, 26, 939, 6, 318, 758, 12, 1, 400],
#  [762, 115, 569],
#  [68, 135, 2, 25, 6, 27, 160],
#  [104, 254, 3, 34, 489],
#  [35],
#  [7],
#  [22],
#  [8, 371, 378, 218, 3, 76, 54, 4, 841, 354, 862, 9, 219, 12, 24, 48],
#  [935, 1],
#  [414, 19],
#  [2, 441, 4, 940],
#  [19, 1, 193, 134, 76],
#  [609, 609, 948, 232],
#  [2, 202, 2, 67, 19, 199, 415, 208, 414, 134, 42, 6, 130, 496, 496, 208],
#  [52, 3, 50, 323, 1, 770, 9, 22],
#  [62,
#   26,
#   407,
#   28,
#   291,
#   140,
#   3,
#   362,
#   823,
#   24,
#   42,
#   42,
#   502,
#   269,
#   665,
#   3,
#   3,
#   996,
#   621,
#   310,
#   58,
#   787,
#   5,
#   397,
#   6],
#  [417, 51, 166, 151, 38, 14, 47, 545, 19, 223, 648, 79, 706],
#  [217, 180, 288, 355, 255, 42, 43],
#  [11, 450, 1, 2, 242, 147, 35],
#  [14, 122, 369, 13, 5],
#  [188, 1, 89, 379, 142],
#  [763, 2, 11, 191, 541, 3, 3, 604, 3, 599, 64, 49, 570, 184, 38, 160, 7],
#  [324],
#  [603, 11],
#  [265, 130, 314, 107],
#  [1, 14, 3, 354],
#  [38, 130, 41, 2],
#  [385, 216],
#  [302, 591, 991, 27, 21, 591, 112],
#  [],
#  [246, 42, 19, 2],
#  [22, 93, 3],
#  [33, 99, 1, 18, 307, 105, 3, 46, 640, 5],
#  [58],
#  [9, 45, 1, 5],
#  [936, 832, 1, 22],
#  [5],
#  [189, 10],
#  [191, 80],
#  [64, 13, 32, 32],
#  [486, 1, 74, 32],
#  [630, 171, 41, 10],
#  [179],
#  [60, 11, 613],
#  [335, 1, 5],
#  [60, 424, 509, 9, 11],
#  [35, 1, 5],
#  [2, 15],
#  [13, 2, 8, 140, 1],
#  [282, 11, 405, 17, 23, 19, 11],
#  [430, 54, 20, 101, 178, 5],
#  [44, 213, 341],
#  [222, 24, 2, 1, 614, 12],
#  [33, 48, 154, 1, 2],
#  [120, 16, 23, 78],
#  [1, 570, 871, 6, 3, 116],
#  [368],
#  [3, 943, 1],
#  [35, 2, 127, 176, 548],
#  [141, 227, 6, 1, 899, 3],
#  [859, 63, 14, 1, 2, 193, 19, 641, 458],
#  [415, 198, 130, 14, 3, 120, 3],
#  [149, 37, 519, 76],
#  [178],
#  [545, 10, 3, 81, 25, 78],
#  [38, 251],
#  [11, 2],
#  [38, 130, 398],
#  [111, 669, 158, 72, 130, 214, 69],
#  [268, 2, 45, 1],
#  [800, 6, 167, 364, 665, 221, 282, 338, 280, 68, 39, 928, 156],
#  [34, 630, 510, 1, 7, 104, 18, 278, 271, 282, 58],
#  [67, 869, 542, 3],
#  [552, 47],
#  [85],
#  [2, 802, 87, 35],
#  [15, 5],
#  [55, 2, 10, 1, 55, 2, 449, 52, 27, 61, 20, 605],
#  [6,
#   2,
#   32,
#   738,
#   23,
#   346,
#   15,
#   711,
#   177,
#   203,
#   399,
#   16,
#   82,
#   31,
#   42,
#   303,
#   12,
#   58,
#   711,
#   346,
#   6,
#   213,
#   60,
#   85,
#   42,
#   456,
#   3],
#  [8, 62, 1, 423, 3, 238, 115],
#  [],
#  [198],
#  [198, 16],
#  [1, 95, 3, 12, 484, 17, 563],
#  [47],
#  [9, 35, 493],
#  [263, 409, 504, 15, 230, 6, 11, 51],
#  [843, 17, 499, 19, 40],
#  [290, 618, 54],
#  [4, 3, 181, 78, 4, 4, 223],
#  [7],
#  [20, 639, 1, 46, 86, 265, 1],
#  [149,
#   2,
#   10,
#   1,
#   79,
#   51,
#   95,
#   949,
#   567,
#   521,
#   1,
#   93,
#   102,
#   211,
#   295,
#   57,
#   9,
#   18,
#   2,
#   56,
#   420,
#   916,
#   109,
#   164,
#   57,
#   294,
#   275,
#   2,
#   37,
#   30,
#   16,
#   1],
#  [],
#  [35, 137],
#  [13, 5],
#  [1,
#   223,
#   356,
#   2,
#   113,
#   22,
#   1,
#   6,
#   51,
#   116,
#   161,
#   718,
#   882,
#   123,
#   3,
#   10,
#   37,
#   82,
#   331,
#   479,
#   48,
#   764],
#  [220, 85, 842, 13, 85, 34, 189, 42, 3, 42, 2, 4, 13],
#  [81, 29, 81, 6, 50, 28, 2, 182, 87, 1],
#  [13,
#   232,
#   2,
#   719,
#   1,
#   16,
#   970,
#   813,
#   18,
#   6,
#   109,
#   184,
#   418,
#   35,
#   231,
#   14,
#   232,
#   446,
#   685,
#   14,
#   3,
#   116,
#   3,
#   1,
#   86],
#  [499, 223, 650, 650],
#  [84, 20, 71, 287],
#  [249, 92, 51, 5],
#  [8, 7, 1],
#  [9, 216],
#  [31, 530, 89, 1, 530, 13, 46, 2, 53, 319, 46],
#  [908, 80, 119, 530, 357],
#  [],
#  [248, 61],
#  [132, 532, 556, 15, 532, 732, 847, 1, 5],
#  [250, 497, 147, 1, 2],
#  [129,
#   109,
#   330,
#   2,
#   442,
#   615,
#   6,
#   76,
#   83,
#   225,
#   25,
#   247,
#   9,
#   25,
#   5,
#   940,
#   286,
#   443,
#   314,
#   16,
#   635],
#  [21,
#   17,
#   19,
#   279,
#   59,
#   771,
#   257,
#   5,
#   57,
#   39,
#   9,
#   5,
#   20,
#   26,
#   105,
#   225,
#   952,
#   17,
#   6,
#   557,
#   170,
#   836,
#   168,
#   65,
#   12,
#   279],
#  [1, 369, 2, 454, 19, 12],
#  [548],
#  [1, 3, 248, 111, 363, 3],
#  [600, 911, 235, 4, 51],
#  [],
#  [908, 3, 16, 53, 164, 707, 546, 16, 229, 67, 8, 85, 44, 360],
#  [997,
#   1,
#   79,
#   640,
#   87,
#   909,
#   38,
#   112,
#   67,
#   507,
#   8,
#   399,
#   17,
#   990,
#   369,
#   864,
#   213,
#   50,
#   817,
#   1,
#   15,
#   69],
#  [119, 2, 80],
#  [46, 2],
#  [236, 114],
#  [1, 5, 83, 2, 435, 1, 31, 33, 5],
#  [311, 74],
#  [9, 100, 1, 5],
#  [685, 2, 550, 77],
#  [41, 393, 71, 482],
#  [9,
#   415,
#   115,
#   1,
#   485,
#   76,
#   416,
#   133,
#   437,
#   2,
#   222,
#   141,
#   297,
#   187,
#   57,
#   476,
#   297,
#   1],
#  [27, 27, 208, 9, 22],
#  [30,
#   348,
#   38,
#   375,
#   215,
#   19,
#   28,
#   11,
#   3,
#   26,
#   461,
#   8,
#   682,
#   715,
#   283,
#   4,
#   212,
#   137,
#   34,
#   358,
#   12],
#  [719, 415, 53],
#  [99, 293, 65, 532, 84, 3, 15],
#  [94],
#  [142, 43, 59],
#  [535],
#  [7, 280, 53, 4, 293, 98, 59, 499, 3],
#  [51, 395, 28, 50],
#  [22, 1],
#  [8, 120, 35, 2, 300, 268, 320, 998],
#  [3, 3, 323, 848, 8, 1],
#  [105, 227, 94, 763, 32, 268, 318, 16, 390, 3],
#  [90, 347, 493, 71, 87, 113, 512, 155, 215, 19],
#  [249, 300, 48, 7, 32, 283, 24, 117, 522, 152],
#  [617],
#  [508, 563, 15, 417, 18, 55, 185, 379, 8, 162],
#  [75, 483, 1, 61, 28, 2, 75, 206, 61],
#  [814, 1, 691, 6, 462, 549, 71, 491, 55, 16, 491, 3, 6, 49, 462],
#  [192, 17, 419],
#  [225, 384, 258, 103, 279],
#  [208, 27],
#  [52,
#   3,
#   10,
#   37,
#   195,
#   10,
#   16,
#   3,
#   235,
#   3,
#   53,
#   3,
#   24,
#   605,
#   348,
#   3,
#   665,
#   3,
#   115,
#   7,
#   112],
#  [37, 3, 188, 1, 542, 324, 5, 188, 1, 971],
#  [369, 82],
#  [9, 8, 253, 224, 9],
#  [154, 50],
#  [512, 254, 32, 32, 9, 3],
#  [1],
#  [27, 1],
#  [58, 558, 4, 34, 2],
#  [144, 26, 11, 145, 52, 1],
#  [84, 9, 53, 4, 94, 22],
#  [8, 8, 666],
#  [17, 3, 16, 171],
#  [8, 391, 227, 112, 1, 6],
#  [396, 476, 1, 84, 463, 21, 211, 4],
#  [51, 124, 44, 324],
#  [77, 156, 121, 1],
#  [762,
#   54,
#   255,
#   872,
#   3,
#   594,
#   76,
#   55,
#   91,
#   2,
#   37,
#   5,
#   65,
#   54,
#   54,
#   234,
#   54,
#   54,
#   54,
#   54,
#   94,
#   4,
#   25],
#  [213, 36, 4, 8, 21, 143],
#  [344, 44, 116, 59, 670, 16, 628, 376, 43, 1, 54, 4, 1],
#  [9, 20, 3, 774, 20, 9, 3],
#  [121, 121],
#  [330, 759, 2, 129, 508, 385, 274, 51, 5],
#  [],
#  [42, 347, 11, 171],
#  [1, 2, 110, 76, 222, 43, 16, 411, 55, 2, 1, 335],
#  [345, 7, 8, 162],
#  [594, 263, 200, 151, 484, 29, 535, 458, 4, 273, 20, 92, 108, 1, 242, 47],
#  [584, 3, 912, 12, 727, 12],
#  [217,
#   667,
#   28,
#   123,
#   1,
#   614,
#   12,
#   2,
#   70,
#   104,
#   165,
#   139,
#   595,
#   139,
#   155,
#   5,
#   12,
#   27,
#   4,
#   13,
#   1,
#   45,
#   1,
#   216],
#  [37, 25, 28, 50, 2, 2, 20, 20, 359, 42, 194, 48, 298, 79, 28, 50],
#  [165, 165],
#  [116, 29, 732, 219],
#  [457, 359, 3, 372, 170, 750, 41, 46],
#  [188, 17, 562, 18, 291, 532, 14, 58, 15],
#  [2, 78],
#  [31],
#  [189, 3, 84],
#  [577, 229, 422, 585, 6],
#  [14, 76, 52],
#  [328, 194, 207, 207, 88, 175],
#  [90, 334, 2, 33, 183, 18, 682, 57, 78],
#  [87, 4],
#  [766, 44, 37, 5, 37, 654],
#  [354, 454],
#  [13, 91, 6],
#  [11, 21, 251, 50, 57, 136],
#  [87, 47, 60, 178, 5, 13, 187],
#  [25, 8],
#  [13, 8, 7, 208, 917],
#  [20],
#  [29, 1, 893, 19, 594, 445, 12, 108],
#  [193, 57, 98, 2, 219],
#  [114, 114],
#  [453, 44],
#  [696, 15, 921, 1, 162, 921],
#  [174, 53, 4, 127, 744, 1],
#  [523, 10, 27, 83, 26, 10, 27, 83, 3, 213, 821],
#  [11, 21, 68],
#  [2, 30, 78, 13, 303, 13, 81, 176],
#  [30, 36, 344, 4, 98, 118],
#  [28, 50, 586, 2],
#  [1, 35, 108],
#  [67, 180, 176, 626, 321, 8, 295, 67, 3, 7, 24, 48, 57, 1, 160, 659, 3],
#  [66, 228, 79, 66, 370, 4],
#  [60, 23, 640, 60, 687],
#  [1, 768, 3, 46, 574],
#  [7, 1],
#  [339, 251],
#  [478, 19],
#  [157, 336],
#  [9, 441, 3, 1],
#  [2, 106, 71, 16, 33, 392, 41, 106, 3, 361],
#  [883, 20, 3, 241, 592, 56, 224, 387, 2],
#  [125],
#  [367],
#  [138, 950, 14, 2, 372, 2, 210, 135, 99, 99, 3],
#  [26, 44, 3, 189, 3, 24, 2, 191, 65, 922, 4, 175, 24, 355, 756, 261],
#  [282, 12, 76, 48, 164, 31, 20, 683],
#  [67, 3, 43, 139, 53, 78, 34, 368, 228],
#  [430,
#   32,
#   34,
#   3,
#   379,
#   116,
#   89,
#   1,
#   3,
#   395,
#   276,
#   118,
#   176,
#   32,
#   17,
#   366,
#   17,
#   369,
#   290],
#  [33, 97, 2, 86],
#  [28, 240],
#  [29, 1, 54, 381, 4, 628, 18, 94, 340, 179, 199, 1],
#  [587, 587],
#  [23, 69, 52, 72, 15, 28, 513, 37, 184, 2],
#  [365, 30],
#  [21,
#   8,
#   143,
#   177,
#   35,
#   16,
#   62,
#   29,
#   1,
#   774,
#   661,
#   774,
#   38,
#   160,
#   177,
#   4,
#   605,
#   471,
#   85,
#   127,
#   4,
#   244,
#   28,
#   1,
#   2,
#   808,
#   772],
#  [25],
#  [165, 610, 47, 3, 19],
#  [58, 520, 201, 5, 73, 17, 374, 3, 762, 49, 3, 491, 157, 13, 315],
#  [479, 88, 47, 1],
#  [61, 886],
#  [65, 381, 977, 4, 20, 42, 104, 19, 288, 49, 1],
#  [1, 9, 770, 107, 251],
#  [36, 4],
#  [9, 20, 3, 269, 859, 849, 151, 91, 84, 20],
#  [188, 1, 445, 255, 447, 492, 2, 81, 286],
#  [787,
#   111,
#   3,
#   1,
#   11,
#   310,
#   787,
#   170,
#   33,
#   9,
#   6,
#   311,
#   31,
#   48,
#   521,
#   199,
#   9,
#   363,
#   11],
#  [430, 2],
#  [843, 17, 499],
#  [145, 9, 252, 145, 3, 4],
#  [116, 89, 1, 563, 22, 1, 73, 2, 17, 221, 16],
#  [73, 358, 159, 2, 692],
#  [45, 539],
#  [7],
#  [62, 27, 25, 5],
#  [1, 67, 26, 631, 6, 437, 306, 38, 9, 12, 64],
#  [659, 3, 414, 134],
#  [318, 4, 622],
#  [33,
#   329,
#   760,
#   135,
#   99,
#   99,
#   3,
#   9,
#   720,
#   33,
#   79,
#   14,
#   671,
#   61,
#   223,
#   356,
#   55,
#   2,
#   157,
#   51,
#   754],
#  [62, 24, 3, 175, 50, 6, 3],
#  [792],
#  [119,
#   953,
#   262,
#   53,
#   479,
#   48,
#   113,
#   3,
#   1,
#   270,
#   796,
#   384,
#   59,
#   670,
#   270,
#   194,
#   271,
#   260,
#   93],
#  [196, 841, 145],
#  [447, 6, 2, 508, 46, 57, 18, 230, 6],
#  [563, 11, 1, 312, 111, 7, 214, 173, 197, 6, 20, 3],
#  [802, 953, 168, 6, 72, 43, 3, 31, 102, 20, 106, 87, 54, 4],
#  [117, 41, 636, 10, 36, 4, 346],
#  [935, 2, 11, 20, 3, 53, 31, 71, 41],
#  [92],
#  [415, 606, 139],
#  [40],
#  [1, 666],
#  [74, 351, 43, 44, 23, 375],
#  [7, 531, 984, 290, 195],
#  [206, 2, 521],
#  [305],
#  [3, 26, 113, 263, 313, 409, 91, 6, 81],
#  [8, 109, 1, 33, 103, 716, 940, 5],
#  [999, 563, 1],
#  [73, 358, 17, 3, 2],
#  [41, 3, 139, 32, 4],
#  [486, 22, 64],
#  [],
#  [33, 531, 177, 3],
#  [59, 18, 1, 212, 525, 110, 14, 2],
#  [249, 672, 139, 109, 114],
#  [168, 1, 17, 257, 7, 174, 271],
#  [74, 5, 662, 702, 41, 43],
#  [633, 31, 10, 3, 181],
#  [1, 552, 355, 1, 536, 63, 176],
#  [332, 33, 319, 3, 50, 3, 787, 42, 5, 455, 229],
#  [296,
#   475,
#   59,
#   8,
#   175,
#   547,
#   22,
#   14,
#   6,
#   2,
#   3,
#   677,
#   788,
#   565,
#   159,
#   12,
#   82,
#   547,
#   8,
#   803],
#  [742, 1, 118, 207, 418, 196],
#  [4],
#  [11],
#  [44, 189, 60, 3, 60, 3, 216],
#  [4, 113],
#  [37, 30, 1],
#  [54, 4, 253, 141, 1, 18, 134, 3, 141, 3],
#  [31, 20, 7, 3, 181],
#  [1, 163, 49, 829, 3],
#  [149],
#  [60, 35, 102],
#  [446, 3, 120, 304],
#  [120, 16, 218, 320],
#  [4, 969, 539, 716, 751, 768, 70, 7, 1],
#  [1, 350, 34, 22, 49],
#  [192, 12, 341, 30],
#  [496, 3, 2, 366, 86, 48, 12, 367],
#  [280,
#   11,
#   181,
#   46,
#   104,
#   192,
#   637,
#   3,
#   586,
#   224,
#   161,
#   46,
#   38,
#   4,
#   68,
#   21,
#   143,
#   46],
#  [784,
#   6,
#   166,
#   6,
#   3,
#   10,
#   1,
#   3,
#   82,
#   645,
#   3,
#   436,
#   4,
#   82,
#   56,
#   3,
#   715,
#   287,
#   482,
#   88,
#   3,
#   4,
#   448,
#   19],
#  [217, 894, 45, 1, 28, 71, 9, 1, 268, 2],
#  [326,
#   148,
#   323,
#   301,
#   319,
#   362,
#   882,
#   3,
#   332,
#   148,
#   129,
#   139,
#   199,
#   2,
#   1,
#   567,
#   22,
#   27,
#   1],
#  [192, 1],
#  [461,
#   447,
#   826,
#   356,
#   2,
#   106,
#   71,
#   8,
#   36,
#   4,
#   191,
#   785,
#   745,
#   55,
#   2,
#   11,
#   382,
#   36,
#   4,
#   347,
#   263,
#   249,
#   447,
#   826,
#   59,
#   12],
#  [43, 254],
#  [1, 13, 28, 240, 8, 140, 12],
#  [429, 626, 3, 5, 12],
#  [100, 196],
#  [19, 419, 72, 62, 562, 9, 37, 47, 46, 2, 84],
#  [258, 174, 23, 336, 251, 13],
#  [4, 3, 181],
#  [886, 567, 319, 929],
#  [162, 12, 613],
#  [37, 623, 10, 16, 6, 1],
#  [13, 182, 40, 620, 1, 509],
#  [12,
#   16,
#   641,
#   38,
#   511,
#   607,
#   547,
#   422,
#   200,
#   49,
#   12,
#   72,
#   177,
#   4,
#   67,
#   155,
#   454,
#   677,
#   312,
#   268,
#   83],
#  [666, 271, 91, 244],
#  [9, 35, 2],
#  [17, 12, 76, 716, 29, 1, 18, 235, 547, 466, 3, 3, 505, 12, 6, 2, 224],
#  [185, 263, 239, 17, 2, 1, 210, 103, 50, 32],
#  [178, 192, 202, 10],
#  [9, 620, 930, 28, 28, 2, 202, 2, 1, 205, 49, 76, 48],
#  [546, 2, 471, 179],
#  [23, 66, 668, 54, 181, 4, 834, 34, 707, 646],
#  [34],
#  [551,
#   756,
#   630,
#   50,
#   9,
#   1,
#   44,
#   24,
#   3,
#   36,
#   6,
#   113,
#   124,
#   150,
#   1,
#   5,
#   50,
#   2,
#   113,
#   572],
#  [22, 66, 1],
#  [111,
#   100,
#   1,
#   865,
#   109,
#   197,
#   6,
#   235,
#   1,
#   1,
#   824,
#   458,
#   389,
#   296,
#   14,
#   3,
#   133,
#   110,
#   950,
#   42,
#   50,
#   96,
#   15],
#  [15, 7, 123, 28, 1, 15, 895, 1],
#  [84, 84, 11, 64],
#  [],
#  [99, 741],
#  [10, 207, 317, 3],
#  [9, 187, 2, 19],
#  [140, 61],
#  [74, 17, 29, 373, 477, 18, 26, 105, 597],
#  [182, 299, 694, 87, 1, 52, 3, 1],
#  [322, 132, 1, 523],
#  [217],
#  [173],
#  [5,
#   489,
#   328,
#   295,
#   769,
#   244,
#   194,
#   332,
#   209,
#   606,
#   131,
#   26,
#   24,
#   2,
#   74,
#   15,
#   97,
#   601,
#   3,
#   836,
#   670,
#   489,
#   700,
#   673,
#   89,
#   24],
#  [85, 85, 20, 85, 454, 44],
#  [624],
#  [8, 483, 27, 1, 9, 7],
#  [22, 1],
#  [521, 55, 2, 103, 60, 416, 108, 443, 73, 767, 794, 145, 870, 64, 55, 2, 125],
#  [],
#  [937, 3, 3, 575, 113, 891],
#  [34, 350],
#  [372,
#   402,
#   41,
#   1,
#   56,
#   65,
#   344,
#   427,
#   464,
#   3,
#   105,
#   344,
#   275,
#   65,
#   539,
#   296,
#   2,
#   323,
#   3,
#   900,
#   1],
#  [250, 758, 421, 758, 2, 218, 5],
#  [498, 930, 498],
#  [361],
#  [113, 15, 133],
#  [1, 38, 4],
#  [491, 169, 491, 793, 106, 14, 467, 37, 3],
#  [20],
#  [2, 1, 36, 6, 331, 27],
#  [42, 50, 18, 1],
#  [180, 17, 3, 3],
#  [36, 4, 270, 386, 3, 4],
#  [349, 665, 3, 622, 978, 10],
#  [635, 635, 172],
#  [325, 75, 140],
#  [327, 47, 2, 7, 760, 76, 48],
#  [9, 22, 5, 61, 20, 8, 7],
#  [69, 11, 2, 1],
#  [37,
#   28,
#   371,
#   99,
#   1,
#   56,
#   8,
#   140,
#   321,
#   913,
#   538,
#   144,
#   170,
#   721,
#   140,
#   56,
#   12,
#   3],
#  [2],
#  [120, 727, 452, 34, 3, 3, 310],
#  [3, 157, 265],
#  [31, 271, 20, 948, 286, 7],
#  [9, 180, 593, 2],
#  [814, 372, 372, 3, 24],
#  [144, 950, 92],
#  [2, 50, 203, 19, 2, 32],
#  [149, 431, 344, 65, 267, 57],
#  [59, 16, 180, 41, 2, 468, 51, 17, 505],
#  [126, 542, 15, 1, 2, 28, 50, 1],
#  [6, 4],
#  [792, 331, 67, 489, 582, 3, 17, 101, 505, 273, 78],
#  [305, 111, 66, 130],
#  [1,
#   5,
#   9,
#   970,
#   376,
#   133,
#   52,
#   170,
#   750,
#   52,
#   3,
#   110,
#   9,
#   686,
#   219,
#   56,
#   374,
#   376,
#   1,
#   9,
#   145],
#  [557, 690, 951, 418],
#  [27, 1],
#  [263, 178, 204, 1, 92],
#  [570, 306, 43, 130, 2, 396, 19, 71, 31, 662, 4, 329],
#  [69, 1],
#  [1, 21, 143, 235, 46, 78],
#  [844, 106, 3, 1, 111, 15],
#  [225, 409, 28, 1, 281],
#  [62, 24, 3, 18, 1, 5, 56, 26, 14, 712, 26, 12, 167],
#  [13, 36, 4, 1, 818, 1, 876, 19, 1],
#  [582, 20, 3, 6, 294],
#  [27, 27, 27],
#  [577, 397, 957, 455, 409, 326, 4, 12],
#  [206, 253, 206, 260],
#  [263, 185, 28, 19, 30, 32],
#  [9, 22, 1],
#  [222, 1, 77, 219, 50, 57, 323, 195, 610, 20, 39],
#  [306, 77, 20, 423, 54, 37, 75, 30, 413, 565],
#  [3, 14],
#  [499,
#   492,
#   3,
#   69,
#   2,
#   273,
#   520,
#   784,
#   187,
#   427,
#   490,
#   520,
#   13,
#   187,
#   496,
#   496,
#   126,
#   6,
#   220,
#   25,
#   52,
#   42,
#   128,
#   75,
#   784,
#   187],
#  [896, 2, 412, 143, 38, 4, 1],
#  [190, 16, 1, 100, 92, 1],
#  [13, 89, 1, 543, 3, 978, 3, 16, 73, 1, 2, 42, 244, 303, 13],
#  [155, 6, 624],
#  [692, 300, 649],
#  [119, 153, 746, 224, 106, 272, 55, 2],
#  [131, 504],
#  [20, 15, 4, 364, 342, 2, 4, 1],
#  [709, 588, 67, 775, 169, 5, 7, 12, 166, 251],
#  [489, 2, 8, 30, 1],
#  [56, 22, 32, 64],
#  [7, 22, 15, 22],
#  [45, 94],
#  [984, 122, 1, 54, 147, 48],
#  [247,
#   36,
#   6,
#   212,
#   36,
#   4,
#   415,
#   963,
#   67,
#   399,
#   593,
#   2,
#   13,
#   399,
#   11,
#   2,
#   13,
#   595,
#   257,
#   74,
#   5,
#   803,
#   67,
#   98,
#   246,
#   3,
#   251,
#   5],
#  [479, 48, 145],
#  [2],
#  [84, 81, 81, 5],
#  [697, 1, 201, 860, 28, 860, 114],
#  [34, 1, 823, 6, 38, 190, 216, 5, 1, 174],
#  [34, 14, 393, 3, 1, 38, 8, 42, 3, 17, 70, 76, 157, 529],
#  [398, 27, 1],
#  [403, 1],
#  [21, 578],
#  [28, 880],
#  [165],
#  [479, 99, 708, 3, 1, 689, 236, 503, 13],
#  [59, 499, 624, 3, 15],
#  [11, 206],
#  [340, 213, 985, 3, 12, 2, 1],
#  [545, 147, 377, 44, 47, 952, 8],
#  [225, 2, 75, 11, 545, 50, 361],
#  [77,
#   20,
#   196,
#   100,
#   1,
#   5,
#   717,
#   150,
#   336,
#   132,
#   405,
#   815,
#   852,
#   10,
#   211,
#   62,
#   98,
#   573,
#   101,
#   213,
#   14,
#   498],
#  [21,
#   68,
#   136,
#   421,
#   83,
#   9,
#   128,
#   42,
#   42,
#   677,
#   9,
#   135,
#   930,
#   128,
#   2,
#   728,
#   667,
#   236,
#   15,
#   53],
#  [116, 21, 136, 6],
#  [218, 766, 245, 40, 809, 14, 114, 501],
#  [953, 494, 1, 861, 430, 776, 122, 3],
#  [],
#  [748, 853, 388, 99, 1],
#  [738, 133, 941, 2, 218, 7],
#  [2, 40, 1, 12, 32, 708, 33, 64],
#  [9, 376, 22, 1, 1],
#  [142, 817, 1, 23, 823, 4, 472, 14, 3],
#  [13, 339, 173, 207, 69, 339, 348, 661, 89, 207, 697],
#  [34, 36, 4, 61],
#  [804, 301],
#  [31, 392, 106],
#  [34, 2],
#  [],
#  [94],
#  [13, 187, 1],
#  [41, 16, 26, 139, 369, 526, 141, 19, 177, 110, 59, 670, 16, 282],
#  [834],
#  [476, 11, 2],
#  [11],
#  [345, 345, 14, 2, 42, 36, 6],
#  [733, 176, 1, 6, 209, 152],
#  [73, 481, 132, 233, 365, 2],
#  [805, 2, 9, 11, 41, 2, 2, 1, 22],
#  [189, 16, 2, 18, 672, 3],
#  [459, 789, 876, 110],
#  [800, 353, 20, 67, 20, 8, 3],
#  [14, 76, 1, 169, 259, 33, 197, 2, 77, 197, 6, 16, 31, 180, 92],
#  [775, 2, 11, 31, 38, 172],
#  [752, 111, 35, 18],
#  [51, 661, 374, 605],
#  [64, 14, 381, 4, 31],
#  [90,
#   396,
#   7,
#   32,
#   260,
#   264,
#   662,
#   1,
#   7,
#   11,
#   12,
#   260,
#   88,
#   3,
#   3,
#   32,
#   13,
#   74,
#   23,
#   67,
#   801,
#   381,
#   4,
#   74,
#   64,
#   32,
#   68,
#   162,
#   979,
#   195,
#   10,
#   1,
#   473,
#   205],
#  [499, 28, 50, 175, 99],
#  [558, 4, 458, 2, 3, 12],
#  [680, 103, 972, 110, 94, 140, 38, 110, 207],
#  [196, 84, 22],
#  [84, 302, 2, 175],
#  [92, 1],
#  [225, 11],
#  [111,
#   70,
#   7,
#   40,
#   559,
#   10,
#   1,
#   226,
#   228,
#   15,
#   318,
#   25,
#   15,
#   25,
#   12,
#   76,
#   5,
#   20,
#   77,
#   92,
#   837,
#   246,
#   98,
#   39,
#   43,
#   5,
#   116,
#   65,
#   916,
#   142],
#  [133, 79, 2, 240, 101],
#  [329, 329],
#  [835, 26, 892, 96, 563],
#  [34, 19],
#  [2, 383, 94, 113, 22, 51, 567, 22, 5, 205],
#  [],
#  [447, 618],
#  [58, 996, 655, 3, 4, 142, 13, 30],
#  [821, 1, 539, 8, 428, 19],
#  [17],
#  [336, 1, 15, 336, 1, 27, 6, 593, 39, 2, 213, 14, 68, 44, 91, 63],
#  [881, 3],
#  [9, 250, 224, 108, 189, 10],
#  [814, 200, 4],
#  [19, 123, 2, 216, 305, 126, 40, 2, 381, 977, 4, 29],
#  [7, 111, 77],
#  [19, 57, 523, 216, 5],
#  [456, 39, 606, 242, 721, 323, 4, 111, 305, 1, 160, 877, 23, 6, 16, 12],
#  [7, 6, 3, 49, 154, 102, 505, 331, 10, 47, 10, 10, 70, 250, 2],
#  [140, 696, 216, 14, 134, 8, 628],
#  [17, 28, 13, 27],
#  [78, 148, 40, 191, 13, 31, 663, 322, 45, 1, 163, 78, 13, 1, 2, 43, 78],
#  [398, 271, 27, 1],
#  [1, 69, 243, 30, 463, 245, 18],
#  [23, 66, 36, 39, 207],
#  [410, 622, 1],
#  [3, 3, 46, 33, 433, 753, 577, 227, 18, 12, 1],
#  [27, 40, 1, 5],
#  [17,
#   2,
#   185,
#   362,
#   123,
#   24,
#   3,
#   48,
#   1,
#   817,
#   48,
#   33,
#   665,
#   259,
#   150,
#   918,
#   597,
#   635],
#  [2, 224, 11],
#  [52, 964, 83, 55, 10, 6, 3, 24, 48, 1],
#  [1, 154, 364, 63, 14, 91, 101],
#  [22, 104, 343, 464],
#  [319, 362, 55, 123, 24, 3, 1],
#  [236, 4, 331, 28, 544],
#  [508, 760, 101, 78],
#  [528, 813, 126, 54, 28, 59, 3, 148, 88],
#  [104, 3, 859, 13, 333, 251],
#  [2, 1, 132, 18, 91, 10],
#  [194, 403, 831],
#  [11, 651, 127, 5],
#  [59, 61, 402, 13, 140, 1, 5, 61, 56, 153, 208, 255, 2],
#  [917, 944, 198, 35, 28, 6],
#  [66, 106, 192, 445, 2, 36, 232, 221],
#  [620, 427, 17],
#  [844, 22, 426, 121, 577, 76],
#  [113, 22, 1],
#  [13, 152, 3],
#  [340, 8, 121, 31, 490, 194, 489, 24],
#  [229, 139, 6],
#  [70, 11, 1, 108],
#  [718, 63, 11, 53, 412, 44],
#  [177, 214, 69, 65, 5, 636, 77, 4],
#  [876, 289, 247],
#  [286, 120, 465],
#  [2, 21, 143, 88, 569, 90, 63, 471, 98, 340, 120, 37, 210, 340, 115, 418],
#  [13, 866, 215, 820],
#  [7, 31, 51],
#  [15, 523, 2, 786, 17, 22, 5, 198, 34, 105, 599, 614, 509],
#  [246, 3, 240, 134],
#  [38, 130, 529, 43, 57, 36, 4],
#  [65, 5, 32],
#  [3, 64],
#  [45, 1],
#  [8, 886, 10, 14, 393, 153, 71, 1, 119, 886, 8, 94],
#  [9, 447, 40, 28, 30, 74],
#  [441, 17, 1],
#  [113, 22, 1, 10, 273, 106],
#  [33, 78, 893, 1],
#  [500, 160, 1, 542],
#  [1, 98, 867, 756, 1, 15, 53],
#  [936, 7, 568, 263, 128, 6, 730, 281, 123, 2, 89, 1, 32],
#  [456, 9, 145],
#  [478, 8, 7, 478, 8],
#  [3, 4],
#  [85],
#  [29, 1, 70, 7],
#  [396, 639, 294],
#  [347, 120, 61, 228, 1],
#  [626, 9, 11, 2, 20, 7, 10, 3, 24, 202, 3, 32],
#  [288, 474, 2, 300],
#  [755, 1, 164, 66, 14, 2, 57, 245, 19, 10],
#  [1],
#  [149, 21, 10, 10, 12],
#  [163, 379, 3, 32, 12, 24, 48, 103],
#  [188, 1, 80, 2, 161, 1],
#  [13,
#   58,
#   15,
#   613,
#   696,
#   80,
#   696,
#   421,
#   83,
#   2,
#   26,
#   191,
#   58,
#   349,
#   245,
#   41,
#   40,
#   451,
#   78,
#   40,
#   2,
#   8,
#   30,
#   13,
#   208,
#   82,
#   448,
#   59,
#   46,
#   216],
#  [135, 99, 99, 223, 356, 175],
#  [96, 7],
#  [2, 1, 134, 715, 68, 39, 167, 611, 6],
#  [13, 68, 314, 44, 1, 63, 5, 13, 30, 378],
#  [13, 44, 327, 57, 604, 26, 4, 235, 836, 53, 12, 60, 687],
#  [394, 203, 762, 133, 155, 369],
#  [32, 232, 142, 690, 418, 3],
#  [149, 44, 345, 581, 4],
#  [1, 333],
#  [35, 27, 103],
#  [15, 163, 123, 54, 116, 89, 239, 631, 6],
#  [1,
#   275,
#   3,
#   322,
#   14,
#   992,
#   3,
#   674,
#   588,
#   187,
#   438,
#   780,
#   198,
#   14,
#   15,
#   411,
#   256,
#   33,
#   51,
#   169,
#   992,
#   175,
#   450,
#   3],
#  [60, 27, 5, 61, 179, 108],
#  [17, 332, 153, 312, 439],
#  [741, 901, 203, 2, 153],
#  [229, 392],
#  [12, 817, 77],
#  [41, 2, 210, 233],
#  [31, 180, 30, 3, 30],
#  [276, 168, 1],
#  [119, 13, 35, 2, 171],
#  [9,
#   22,
#   1,
#   56,
#   138,
#   241,
#   9,
#   318,
#   4,
#   182,
#   467,
#   29,
#   1,
#   10,
#   160,
#   57,
#   222,
#   254,
#   182,
#   87,
#   1],
#  [2, 314, 71],
#  [940, 83, 471, 266, 3],
#  [28, 715, 210, 182, 87, 1],
#  [2, 2, 390, 1, 93, 18, 26, 303],
#  [104, 38, 156, 46, 980, 167, 845, 5, 1],
#  [886,
#   82,
#   675,
#   148,
#   422,
#   259,
#   1,
#   980,
#   471,
#   335,
#   5,
#   113,
#   155,
#   49,
#   500,
#   10,
#   619,
#   380,
#   5],
#  [710, 4],
#  [21, 143, 496, 3, 659, 1],
#  [72, 35, 57, 15, 2, 552, 57, 79, 3, 3, 27, 109, 107],
#  [149,
#   277,
#   3,
#   79,
#   9,
#   120,
#   419,
#   3,
#   383,
#   226,
#   91,
#   429,
#   718,
#   6,
#   76,
#   76,
#   26,
#   6,
#   263,
#   219,
#   1],
#  [100, 1, 5],
#  [9, 450],
#  [800, 887, 685, 3, 3],
#  [9, 76, 5],
#  [941, 102, 7, 26, 1, 26],
#  [2, 691, 15, 293, 52, 227, 15, 3, 3, 225, 26, 105, 7, 1, 614, 12],
#  [74, 45, 265, 9, 665, 3],
#  [],
#  [257, 11],
#  [7, 92],
#  [1, 2, 667, 11],
#  [183, 25],
#  [157, 957, 604, 6, 3, 6, 22, 952],
#  [526, 189, 3, 2, 15, 92],
#  [339, 310],
#  [329, 88, 3, 26, 103, 755, 51],
#  [13, 29, 12, 1, 37, 519, 266, 4, 120, 16, 719, 277, 646, 2, 58, 13, 12],
#  [11, 1, 5, 547, 29, 686, 6, 70, 11, 12, 247, 247],
#  [2],
#  [9, 681],
#  [308],
#  [11],
#  [34, 49, 145],
#  [141, 1, 638, 680, 326, 169, 14, 591, 3, 295, 1, 164, 470, 8, 127, 644, 108],
#  [579, 4, 149, 857, 30],
#  [183, 183, 6, 133, 17, 3, 97],
#  [908, 3, 908],
#  [3, 6],
#  [80, 26, 15, 60, 107, 216],
#  [775, 3, 836, 775, 304, 3],
#  [22, 10],
#  [36, 435],
#  [245, 40, 50, 215, 18, 371],
#  [14, 2, 1, 124, 140, 1],
#  [592, 17, 827, 287, 887, 4, 282, 82, 1, 67, 75, 172, 166, 816, 3, 40, 75, 48],
#  [11,
#   808,
#   593,
#   291,
#   114,
#   3,
#   54,
#   19,
#   34,
#   194,
#   48,
#   981,
#   453,
#   154,
#   194,
#   48,
#   981,
#   42,
#   773,
#   3,
#   26,
#   3,
#   6,
#   188,
#   323,
#   475,
#   14,
#   1,
#   5,
#   305],
#  [680, 15],
#  [21],
#  [243, 30, 45, 1, 775, 30],
#  [366, 3, 187, 6, 184, 764, 483, 690, 40, 161],
#  [73, 39, 2, 192, 74, 5, 61, 440, 602, 15, 338, 20, 475, 162],
#  [180, 96, 3, 4, 591, 4, 53, 17, 20, 3, 2],
#  [83, 175, 49, 2],
#  [31, 30],
#  [],
#  [107, 266, 914, 155, 105, 3, 155, 26, 275, 891, 936, 449, 344, 799, 567, 3],
#  [150, 32],
#  [211, 2, 191, 68, 3],
#  [19, 13, 401, 69],
#  [33, 99, 741, 425, 402, 22, 958],
#  [36, 8, 4, 37, 30],
#  [128, 108],
#  [116,
#   207,
#   649,
#   207,
#   46,
#   33,
#   95,
#   455,
#   242,
#   42,
#   50,
#   595,
#   82,
#   388,
#   253,
#   10,
#   122,
#   25,
#   477,
#   14,
#   195,
#   3,
#   10,
#   15,
#   33],
#  [28, 6, 279, 400, 209, 72],
#  [129],
#  [7, 1],
#  [417, 59, 12, 36],
#  [19],
#  [33, 821, 1],
#  [32],
#  [44],
#  [104, 24, 14, 18, 631],
#  [23, 669, 31, 20, 335, 5, 418, 554],
#  [113, 22],
#  [1, 28, 52, 42, 50, 131, 24, 3, 573, 255, 65, 19, 16, 105, 152, 3],
#  [277, 402, 367],
#  [43, 43],
#  [48, 2, 263, 446, 17, 10, 3, 787, 5, 242, 147, 101, 3],
#  [34, 407],
#  [217, 1, 15, 231, 890, 21, 57, 585, 3, 2, 748, 1],
#  [9, 520, 220, 334, 659, 26, 499, 320, 18, 906, 25, 247, 176],
#  [912, 668, 95, 651, 331, 277, 2, 224, 5],
#  [45, 25],
#  [463, 143, 578, 2, 7],
#  [87],
#  [89, 1, 2, 878, 762, 255, 993, 18, 484, 999, 335, 254],
#  [474, 13, 3],
#  [2, 35, 44, 13, 218, 766, 1, 277, 1],
#  [958],
#  [545, 8, 136, 81],
#  [158, 31, 8, 7, 237, 86, 6, 7, 12, 133, 158, 931, 15, 22, 22],
#  [105, 40, 184, 40],
#  [4, 75],
#  [21,
#   8,
#   143,
#   146,
#   14,
#   71,
#   626,
#   735,
#   498,
#   3,
#   67,
#   47,
#   157,
#   26,
#   106,
#   825,
#   282,
#   103,
#   148,
#   323,
#   729,
#   17,
#   2,
#   96,
#   305,
#   4],
#  [247, 25, 1, 191, 1, 601, 365],
#  [205, 810, 6, 2, 1],
#  [886, 1],
#  [66, 60, 256, 19, 2],
#  [],
#  [816, 1, 82, 44],
#  [72, 743, 4, 18, 417, 286],
#  [595, 1, 13, 2],
#  [73, 39, 2, 407, 1, 257, 85],
#  [36, 6, 186, 10, 410, 646, 873],
#  [17, 83, 53, 652],
#  [132, 1, 17, 91, 76, 495],
#  [317, 126, 12, 6, 39, 2, 13, 37, 30],
#  [698,
#   3,
#   181,
#   46,
#   698,
#   19,
#   54,
#   19,
#   698,
#   3,
#   19,
#   3,
#   134,
#   698,
#   104,
#   156,
#   46,
#   181,
#   910,
#   2,
#   181,
#   256,
#   545,
#   10,
#   3],
#  [660, 1, 7],
#  [45, 45, 45, 45, 45, 45, 45, 45],
#  [70, 11, 2, 206],
#  [37, 516, 2, 9, 135, 25, 61],
#  [96, 264, 2, 3, 9, 44, 3],
#  [4],
#  [3, 51],
#  [41, 46, 2, 3, 181, 781, 124, 72, 165],
#  [151, 24, 3, 151, 16, 53],
#  [11, 6, 1, 5, 56, 107, 431, 109],
#  [34, 44, 2, 2, 538, 3, 13, 4, 58, 34, 1, 15],
#  [13,
#   414,
#   46,
#   57,
#   214,
#   3,
#   28,
#   9,
#   8,
#   35,
#   8,
#   1,
#   9,
#   63,
#   467,
#   13,
#   479,
#   233,
#   2,
#   68,
#   240,
#   61],
#  [3, 242],
#  [281],
#  [21, 464, 131, 24, 48],
#  [620, 426, 3],
#  [8, 35, 2, 55, 2, 4],
#  [574, 142, 60, 74, 5],
#  [268, 687],
#  [132, 53, 188, 32],
#  [303, 47, 32],
#  [124, 266, 6, 502, 1, 2, 5, 155, 139, 123, 2, 3, 1],
#  [24, 2, 3, 67, 20, 7],
#  [695, 3, 42, 3, 3, 102, 82, 269, 921, 104, 282, 618],
#  [59],
#  [334, 61],
#  [155,
#   63,
#   261,
#   404,
#   603,
#   232,
#   338,
#   149,
#   1,
#   160,
#   319,
#   615,
#   84,
#   683,
#   478,
#   158,
#   80,
#   88,
#   3,
#   3],
#  [330, 138, 2, 138, 80, 108, 908, 105, 152],
#  [39, 593, 2, 257],
#  [],
#  [2, 10, 1],
#  [146, 511],
#  [34, 40, 15],
#  [320, 16, 231, 890, 43],
#  [4, 23, 97, 279, 19],
#  [449, 7, 33, 307, 892, 182, 86, 87],
#  [645, 402, 74, 1, 11, 26, 211, 2, 208],
#  [458, 228, 303, 42, 50, 181, 23, 10, 76],
#  [58, 15],
#  [69, 341, 101, 51, 69],
#  [73, 24, 440, 595, 1, 90, 869, 22, 1, 5, 12],
#  [3, 697, 195, 3, 550, 1],
#  [641, 649, 1, 87, 26, 3, 26, 72, 186, 93, 3, 1, 141, 203, 196],
#  [350, 248, 241, 2, 1, 241, 7],
#  [111, 485, 305],
#  [],
#  [3, 117, 22, 51, 113, 362, 24, 261, 3, 823, 6, 292, 105, 150, 918, 597],
#  [149, 3, 3],
#  [316, 486, 1, 532, 144, 91],
#  [3, 49, 244, 260, 193, 193, 88, 785, 61],
#  [419, 10, 16, 854, 394, 42],
#  [473,
#   300,
#   514,
#   2,
#   296,
#   146,
#   160,
#   117,
#   130,
#   10,
#   38,
#   117,
#   333,
#   4,
#   31,
#   393,
#   237,
#   234,
#   441,
#   365,
#   64,
#   473,
#   453,
#   393],
#  [45, 12, 358, 99],
#  [106, 10, 26, 15, 3],
#  [11,
#   2,
#   354,
#   15,
#   533,
#   973,
#   423,
#   57,
#   5,
#   41,
#   115,
#   51,
#   15,
#   50,
#   306,
#   306,
#   158,
#   31,
#   20,
#   5],
#  [358,
#   2,
#   47,
#   1,
#   855,
#   17,
#   654,
#   117,
#   2,
#   785,
#   200,
#   2,
#   1,
#   60,
#   214,
#   10,
#   249,
#   23,
#   421,
#   66,
#   7,
#   1,
#   551,
#   15,
#   1,
#   2,
#   133,
#   26],
#  [15, 315, 10, 94, 47],
#  [327, 17, 102, 30, 149, 44, 208],
#  [148, 149, 167, 40, 50, 29, 144, 6],
#  [9, 52, 362, 55, 24, 12, 27, 644],
#  [38, 95, 9, 43],
#  [676, 237, 171, 127, 490],
#  [859, 2, 1, 257, 44],
#  [560, 14, 572, 3, 276],
#  [163, 8, 44, 298, 710, 4],
#  [13, 45, 1, 30, 139, 53, 212, 137],
#  [160],
#  [923, 1, 685, 103, 275, 380, 165],
#  [1, 450, 91, 897, 56, 844, 83, 68, 39, 10, 6, 181, 46, 797],
#  [13,
#   68,
#   36,
#   4,
#   27,
#   4,
#   1,
#   63,
#   176,
#   237,
#   103,
#   157,
#   436,
#   3,
#   163,
#   16,
#   64,
#   560,
#   652,
#   10,
#   162,
#   440,
#   8,
#   162,
#   979,
#   31,
#   20,
#   103],
#  [22, 25],
#  [873, 748, 131, 10, 118, 5, 14, 18, 7, 67, 342, 186, 69, 481, 10, 57, 323, 3],
#  [534, 534, 49, 534, 15, 100, 183, 94, 148, 418, 828, 686],
#  [44, 247, 23, 32],
#  [54, 4, 22],
#  [47, 7, 1],
#  [19, 147, 23, 648, 98, 804, 804, 804, 650],
#  [4, 370, 4],
#  [291, 959, 42, 122],
#  [397, 86, 2, 795, 23],
#  [22, 25],
#  [151, 172, 105, 5],
#  [54, 4, 67, 227],
#  [8, 8, 206, 1],
#  [625, 188, 657],
#  [59, 173, 26, 562, 124, 958],
#  [665, 248, 83, 5, 249, 6, 7, 51],
#  [240],
#  [782, 986],
#  [138, 352, 102, 7, 34, 49],
#  [91],
#  [38, 26, 689, 924, 56, 14, 384, 545, 19],
#  [85, 60, 85, 56, 267, 75, 142, 44],
#  [516, 55, 2, 174, 99, 99, 290, 186, 3, 26, 342, 81, 14],
#  [138, 102, 7],
#  [347, 12, 184, 66, 7],
#  [91, 418, 1, 5],
#  [470, 472, 308, 360, 7, 38, 43],
#  [513, 15, 1, 212, 137],
#  [17, 956, 42, 6, 81, 205, 24, 3, 1, 13, 317, 54],
#  [625, 1],
#  [53, 3],
#  [36, 244, 385],
#  [13, 41, 18, 294],
#  [334, 163, 71, 644],
#  [841, 271, 110, 271, 123, 319, 18, 1],
#  [174, 336, 1, 879],
#  [70,
#   111,
#   70,
#   7,
#   38,
#   130,
#   925,
#   26,
#   939,
#   62,
#   6,
#   194,
#   48,
#   981,
#   769,
#   14,
#   610,
#   205,
#   195,
#   534,
#   3,
#   41,
#   14,
#   849,
#   10,
#   129,
#   195,
#   481,
#   6],
#  [340, 49, 229, 392, 47, 364, 1, 60, 324, 5, 66, 162, 42, 23, 251],
#  [448, 44, 642, 377, 11],
#  [8, 5, 233, 23, 7, 141, 188, 233, 14, 683],
#  [278, 376, 3],
#  [16, 116, 129],
#  [19,
#   34,
#   617,
#   66,
#   15,
#   230,
#   226,
#   77,
#   813,
#   141,
#   7,
#   516,
#   730,
#   335,
#   534,
#   79,
#   21,
#   8,
#   217],
#  [20, 7, 38, 45],
#  [13, 44, 239, 17, 2, 4, 228, 2, 279, 215, 19, 954, 3, 268, 2, 13, 334],
#  [21, 211, 11],
#  [7, 3, 310, 78],
#  [1, 508, 1, 958],
#  [211],
#  [8, 14, 125, 2, 210, 650],
#  [29, 80, 26, 333, 577, 425],
#  [121, 3, 110, 53, 1, 36, 4, 43, 3],
#  [198, 35, 14, 2, 9, 35],
#  [11],
#  [159, 2, 357, 24, 48, 1],
#  [109, 243, 6, 23, 122, 308, 360, 41, 750],
#  [122, 221, 41, 18, 1, 22, 53],
#  [206, 206],
#  [341, 99, 4],
#  [1, 22, 324],
#  [],
#  [4],
#  [1, 84, 23, 126, 126, 8, 35],
#  [15, 15],
#  [70, 35, 20, 3, 494, 31, 388, 2, 64],
#  [11],
#  [11, 32],
#  [243, 30, 154, 2, 210, 574, 838, 767, 53],
#  [189, 42, 2, 1, 2, 210, 214, 3, 35, 2],
#  [363, 228, 581, 41, 399, 81, 2, 432, 127, 6, 361, 361, 3, 28, 50, 1],
#  [7, 92],
#  [81, 8, 7, 25, 23, 341, 20, 141, 77, 172, 376],
#  [92, 92, 883, 60, 253, 61],
#  [584, 35, 14, 530, 338, 49, 199, 151, 172, 47, 155, 248, 751, 27, 5],
#  [73, 2, 2, 114, 2, 3, 182, 86, 87, 25],
#  [351, 109, 49, 20, 49, 72, 49, 354, 49],
#  [189, 16, 3, 13, 38, 7, 36, 6],
#  [7],
#  [140],
#  [80],
#  [11, 293],
#  [129, 94, 168],
#  [59, 22, 1],
#  [943, 395, 233],
#  [60, 689, 45, 1, 118, 475, 566],
#  [104],
#  [792],
#  [2, 8, 8, 35],
#  [10, 8, 11],
#  [59, 133, 677, 35, 64],
#  [1, 536, 86, 387, 3, 38, 412, 375, 631, 1, 902, 3, 321],
#  [719, 162, 35, 2, 58],
#  [116, 410, 144, 675, 362, 3, 4],
#  [3, 334, 61],
#  [592, 427, 6],
#  [62, 708, 105, 332, 3, 375, 107],
#  [9, 11, 2, 20, 8, 3],
#  [149, 146, 2, 432, 357, 146, 104, 148, 3, 282, 3],
#  [316, 213, 11, 61],
#  [347, 781, 33, 176],
#  [260, 28, 50],
#  [36, 13, 3, 191, 627, 64],
#  [2, 640, 315],
#  [499],
#  [487, 2, 157, 1, 74, 1, 37, 2, 37, 30, 608, 45, 1],
#  [27,
#   5,
#   593,
#   1,
#   444,
#   56,
#   325,
#   197,
#   876,
#   197,
#   244,
#   17,
#   439,
#   131,
#   642,
#   13,
#   731,
#   547,
#   439,
#   131,
#   137,
#   41,
#   407,
#   163,
#   407,
#   17,
#   325,
#   65,
#   252,
#   13,
#   547,
#   15],
#  [71, 2, 53, 954, 833, 33],
#  [36, 766, 4, 64],
#  [762, 115],
#  [39, 23, 633, 7, 31, 20, 70, 3, 963, 67, 7, 929, 215, 4, 25],
#  [1, 710, 4, 34, 935, 18, 1],
#  [3, 236, 62, 2, 4, 855, 492, 55, 144, 492, 48],
#  [4],
#  [51, 615, 2],
#  [382, 630],
#  [448, 104, 38, 310],
#  [95, 58, 217, 38, 107, 155, 155, 322],
#  [27, 378, 7],
#  [288, 44, 2, 552, 11, 53, 19, 15],
#  [749, 16],
#  [531, 7, 8, 214, 69],
#  [142, 522],
#  [512,
#   96,
#   309,
#   249,
#   561,
#   97,
#   362,
#   195,
#   12,
#   2,
#   13,
#   634,
#   6,
#   12,
#   123,
#   42,
#   53,
#   26,
#   116,
#   52,
#   49,
#   234,
#   19,
#   434,
#   514,
#   62,
#   70],
#  [2, 516, 273, 727, 582, 13, 120],
#  [196, 51, 12, 49, 62, 537, 1, 200],
#  [],
#  [933],
#  [13, 314, 111, 93, 24, 3, 2, 125, 133, 973, 149, 232, 592, 6],
#  [30],
#  [115,
#   1,
#   37,
#   623,
#   730,
#   599,
#   87,
#   5,
#   594,
#   2,
#   1,
#   5,
#   425,
#   1,
#   502,
#   5,
#   95,
#   81,
#   37,
#   623,
#   81,
#   5],
#  [75, 11],
#  [79, 508, 1, 116, 19],
#  [15, 201, 605, 335],
#  [64, 44],
#  [39, 22, 1, 2, 3, 53],
#  [72, 160, 669, 3],
#  [3, 18, 814, 793],
#  [883, 60, 244],
#  [619,
#   253,
#   7,
#   735,
#   37,
#   75,
#   288,
#   527,
#   369,
#   299,
#   43,
#   662,
#   2,
#   218,
#   188,
#   1,
#   800,
#   88,
#   3,
#   6],
#  [23, 177, 69, 616, 3, 528, 25, 51],
#  [97, 67, 253, 39, 2],
#  [911, 51, 28, 18, 15],
#  [874, 295, 1, 18, 302, 45],
#  [155, 274, 72, 355, 6, 500, 3, 16, 131, 4, 783, 2, 33, 127, 1, 18, 304, 26],
#  [56, 825, 7, 1],
#  [745, 492, 47, 728, 2, 168, 1, 22],
#  [635, 3],
#  [728, 568, 285, 91, 66, 404, 477, 633, 306, 1, 131, 82, 513, 190, 870],
#  [4, 8, 3],
#  [3],
#  [10, 307],
#  [21, 136],
#  [31, 18, 230, 249, 230, 6, 677, 2, 3, 279, 19],
#  [133,
#   67,
#   148,
#   14,
#   897,
#   134,
#   21,
#   28,
#   2,
#   3,
#   2,
#   11,
#   2,
#   29,
#   833,
#   2,
#   36,
#   6,
#   125,
#   3,
#   201,
#   423,
#   703,
#   34,
#   148,
#   15],
#  [9, 22, 81, 960, 10, 2, 144, 27, 160],
#  [90, 3, 3, 4],
#  [3, 455, 121, 61],
#  [189, 54, 3, 4, 102, 7, 1],
#  [3, 13, 457, 115, 1, 239, 17, 185, 3],
#  [192, 19],
#  [134, 296, 8, 140, 135, 94, 12],
#  [],
#  [13],
#  [838],
#  [339, 346, 53, 38, 203, 668, 472, 14, 99],
#  [],
#  [13, 8, 314, 64],
#  [201, 10, 2, 39, 2, 9, 570, 4, 2, 40, 32],
#  [30, 45],
#  ...]

# %%
y_train = np.array(train_df['label'])
y_test = np.array(test_df['label'])

# %%
y_train
# Out:
# array([0, 1, 0, ..., 0, 1, 0], dtype=int64)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2,
                                                   random_state = 12)

# %%
lengths = np.array([len(x) for x in x_train])

# %%
# 길이 평균값, 중간값
print(np.mean(lengths), np.median(lengths), np.min(lengths), np.max(lengths))
# Out:
# 6.597802101958048 5.0 0 64

# %%
train_seq = pad_sequences(x_train, maxlen =10)

# %%
print(train_seq.shape)
# Out:
# (114655, 10)

# %%
val_seq = pad_sequences(x_val, maxlen = 10)
test_seq = pad_sequences(x_test, maxlen = 10)

# %%
# 종속변수는 원핫인코딩
y_oh_train = keras.utils.to_categorical(y_train)
y_oh_val = keras.utils.to_categorical(y_val)
y_oh_test = keras.utils.to_categorical(y_test)

# %%
model = keras.Sequential()
model.add(keras.layers.Embedding(1000, 100, input_shape = (10,)))
model.add(keras.layers.Dropout(0.5)) # 밥에 소금, 후추 뿌리는 개념
model.add(keras.layers.Conv1D(64, 5, activation= 'relu'))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.MaxPool1D(4))
model.add(keras.layers.LSTM(128))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(2, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 10, 100)           100000
#
#  dropout_9 (Dropout)         (None, 10, 100)           0
#
#  conv1d_4 (Conv1D)           (None, 6, 64)             32064
#
#  batch_normalization_5 (Bat  (None, 6, 64)             256
#  chNormalization)
#
#  max_pooling1d_4 (MaxPoolin  (None, 1, 64)             0
#  g1D)
#
#  lstm_7 (LSTM)               (None, 128)               98816
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_7 (Dense)             (None, 46)                5934
#
# =================================================================
# Total params: 237070 (926.05 KB)
# Trainable params: 236942 (925.55 KB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = 5e-4) 
model.compile(loss='binary_crossentropy', optimizer = rmsprop ,metrics= ['accuracy'])
early_stopping_cb = keras.callbacks.EarlyStopping(patience=4, restore_best_weights= True)

# %%
history = model.fit(train_seq, y_oh_train, batch_size = 64, epochs = 100,
                   validation_data=(val_seq, y_oh_val),
                   callbacks= [early_stopping_cb])
# Out:
# Epoch 1/100
# 1792/1792 [==============================] - 13s 6ms/step - loss: 0.5863 - accuracy: 0.6643 - val_loss: 0.5458 - val_accuracy: 0.6995
# Epoch 2/100
# 1792/1792 [==============================] - 10s 6ms/step - loss: 0.5480 - accuracy: 0.7004 - val_loss: 0.5397 - val_accuracy: 0.7037
# Epoch 3/100
# 1792/1792 [==============================] - 9s 5ms/step - loss: 0.5406 - accuracy: 0.7062 - val_loss: 0.5371 - val_accuracy: 0.7058
# Epoch 4/100
# 1792/1792 [==============================] - 10s 6ms/step - loss: 0.5367 - accuracy: 0.7083 - val_loss: 0.5387 - val_accuracy: 0.7051
# Epoch 5/100
# 1792/1792 [==============================] - 10s 5ms/step - loss: 0.5337 - accuracy: 0.7111 - val_loss: 0.5351 - val_accuracy: 0.7078
# Epoch 6/100
# 1792/1792 [==============================] - 10s 5ms/step - loss: 0.5308 - accuracy: 0.7128 - val_loss: 0.5342 - val_accuracy: 0.7076
# Epoch 7/100
# 1792/1792 [==============================] - 10s 6ms/step - loss: 0.5272 - accuracy: 0.7150 - val_loss: 0.5355 - val_accuracy: 0.7086
# Epoch 8/100
# 1792/1792 [==============================] - 10s 6ms/step - loss: 0.5261 - accuracy: 0.7174 - val_loss: 0.5337 - val_accuracy: 0.7077
# Epoch 9/100
# 1792/1792 [==============================] - 10s 5ms/step - loss: 0.5243 - accuracy: 0.7180 - val_loss: 0.5353 - val_accuracy: 0.7091
# Epoch 10/100
# 1792/1792 [==============================] - 10s 5ms/step - loss: 0.5216 - accuracy: 0.7199 - val_loss: 0.5329 - val_accuracy: 0.7083
# Epoch 11/100
# 1792/1792 [==============================] - 9s 5ms/step - loss: 0.5200 - accuracy: 0.7211 - val_loss: 0.5350 - val_accuracy: 0.7077
# Epoch 12/100
# 1792/1792 [==============================] - 9s 5ms/step - loss: 0.5202 - accuracy: 0.7216 - val_loss: 0.5328 - val_accuracy: 0.7097
# Epoch 13/100
# 1792/1792 [==============================] - 10s 6ms/step - loss: 0.5169 - accuracy: 0.7231 - val_loss: 0.5329 - val_accuracy: 0.7087
# Epoch 14/100
# 1792/1792 [==============================] - 10s 6ms/step - loss: 0.5169 - accuracy: 0.7237 - val_loss: 0.5330 - val_accuracy: 0.7096
# Epoch 15/100
# 1792/1792 [==============================] - 10s 6ms/step - loss: 0.5149 - accuracy: 0.7254 - val_loss: 0.5332 - val_accuracy: 0.7093
# Epoch 16/100
# 1792/1792 [==============================] - 10s 5ms/step - loss: 0.5137 - accuracy: 0.7257 - val_loss: 0.5341 - val_accuracy: 0.7087
