# %% [markdown]
# # RNN (Recurrent Neural Network) 으로 텍스트 분류하기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.model_selection import train_test_split
from konlpy.tag import Okt
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# ## 데이터 미리보기 및 요약

# %%
df = pd.read_csv("다산콜재단.csv")

# %%
df.head()
# Out:
#      번호  분류                           제목  \
# 0  2645  복지                  아빠 육아휴직 장려금
# 1  2644  경제            [서울산업진흥원] 서울메이드란?
# 2  2642  복지  광진맘택시 운영(임산부,영아 양육가정 전용 택시)
# 3  2641  복지               마포 뇌병변장애인 비전센터
# 4  2640  행정    2021년도 중1·고1 신입생 입학준비금 지원
#
#                                                   내용      내용번호  \
# 0  아빠 육아휴직 장려금   업무개요  남성근로자의 육아휴직을 장려하고 양육에 따른 경...  23522464
# 1  서울산업진흥원 서울메이드란 서울의 감성을 담은 다양하고 새로운 경험을 제공하기 위해...  23194045
# 2  광진맘택시 운영임산부영아 양육가정 전용 택시  업무개요 교통약자인 임산부와 영아가정...  22904492
# 3  마포 뇌병변장애인 비전센터 마포뇌병변장애인 비전센터 운영   구분 내용  목적  학...  22477798
# 4  년도 중고 신입생 입학준비금 지원  업무개요  서울시는 전국 최초로 년도부터 개 자...  22227896
#
#                                                   문서
# 0  아빠 육아휴직 장려금아빠 육아휴직 장려금   업무개요  남성근로자의 육아휴직을 장려...
# 1  [서울산업진흥원] 서울메이드란?서울산업진흥원 서울메이드란 서울의 감성을 담은 다양하...
# 2  광진맘택시 운영(임산부,영아 양육가정 전용 택시)광진맘택시 운영임산부영아 양육가정 ...
# 3  마포 뇌병변장애인 비전센터마포 뇌병변장애인 비전센터 마포뇌병변장애인 비전센터 운영 ...
# 4  2021년도 중1·고1 신입생 입학준비금 지원년도 중고 신입생 입학준비금 지원  업...

# %%
# value_counts()로 분류별 빈도수 확인
df["분류"].value_counts()
# Out:
# 행정    1098
# 경제     823
# 복지     217
# Name: 분류, dtype: int64

# %%
df.shape
# Out:
# (2138, 6)

# %%
# 독립변수(X, 문제)와 종속변수(y, 정답)
x = df["내용"]
y = df["분류"]

# %% [markdown]
# ## label one-hot 형태로 만들기

# %%
# get_dummies 를 사용하여 label 값을 one-hot 형태로 생성
y_oh = pd.get_dummies(y)

# %%
# train_test_split 으로 학습과 예측에 사용할 데이터를 나누기
x_train, x_test, y_train, y_test = train_test_split(x, y_oh, test_size = 0.2, stratify = y_oh, random_state = 12)

# %%
okt = Okt()

# %%
x_train = x_train.map(lambda x: re.sub("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "", x))
x_test = x_test.map(lambda x: re.sub("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "", x))

# %%
# %%time
x_train_token = x_train.map(lambda x: okt.morphs(x, stem = True))
x_test_token = x_test.map(lambda x: okt.morphs(x, stem = True))
# Out:
# Wall time: 36.7 s

# %%
x_train_token
# Out:
# 1188    [안전, 관리, 계획, 서, 작, 성, 대상, 은, 건설, 기술, 관리, 법, 제,...
# 917     [사업, 조정제, 도란, 대기업, 등, 의, 사업, 진출, 로, 중소기업, 의, 경...
# 631     [조산, 원, 의, 시설, 기준, 은, 입원, 실, 분, 만, 실, 이용, 조, 제...
# 1316    [귀농, 하다, 하다, 농업, 창업, 및, 주택, 구입, 지, 원, 사업, 은, 어...
# 1871    [나우, 스타트, 사업, 업무, 개요, 새롭다, 교육, 복지, 의, 기회, 를, 지...
#                               ...
# 16      [사업, 의, 주요, 사업, 분야, 에는, 어떻다, 있다, 사업, 분야, 에는, 산...
# 933     [송파, 뉴스레터, 는, 어떻다, 구성, 되어다, 있다, 돋다, 움, 돋다, 움, ...
# 1044    [옥외광고, 업자, 교육, 밉다, 이수자, 과태료, 부과, 관련, 옥외광고, 물등,...
# 212     [서울시, 부동산, 정보, 통합, 열람, 개요, 한번, 의, 검색, 으로, 해당, ...
# 511     [공공시설, 물, 디자인, 기, 본, 전략, 도, 시공간, 주체, 들, 의, 자유롭...
# Name: 내용, Length: 1710, dtype: object

# %%
x_train_token = x_train_token.map(lambda x: [i for i in x if len(i) > 1])
x_test_token = x_test_token.map(lambda x: [i for i in x if len(i) > 1])

# %%
x_train_token
# Out:
# 1188    [안전, 관리, 계획, 대상, 건설, 기술, 관리, 아래, 같다, 시특법, 규정, ...
# 917     [사업, 조정제, 도란, 대기업, 사업, 진출, 중소기업, 안정, 현저, 하다, 영...
# 631          [조산, 시설, 기준, 입원, 이용, 실조, 제실, 두다, 경우, 소독, 시설]
# 1316    [귀농, 하다, 하다, 농업, 창업, 주택, 구입, 사업, 어떻다, 신청, 하나요,...
# 1871    [나우, 스타트, 사업, 업무, 개요, 새롭다, 교육, 복지, 기회, 지금, 제공,...
#                               ...
# 16      [사업, 주요, 사업, 분야, 에는, 어떻다, 있다, 사업, 분야, 에는, 업체, ...
# 933     [송파, 뉴스레터, 어떻다, 구성, 되어다, 있다, 돋다, 돋다, 돋다, 돋다, 돋...
# 1044    [옥외광고, 업자, 교육, 밉다, 이수자, 과태료, 부과, 관련, 옥외광고, 물등,...
# 212     [서울시, 부동산, 정보, 통합, 열람, 개요, 한번, 검색, 으로, 해당, 필지,...
# 511     [공공시설, 디자인, 전략, 시공간, 주체, 자유롭다, 참여, 살다, 도시, 원천,...
# Name: 내용, Length: 1710, dtype: object

# %% [markdown]
# ## 벡터화
# ### 토큰화
#
# 1. 이 클래스를 사용하면 각 텍스트를 일련의 정수(각 정수는 사전에 있는 토큰의 인덱스임) 또는 단어 수에 따라 각 토큰의 계수가 이진일 수 있는 벡터로 변환하여 텍스트 말뭉치를 벡터화할 수 있습니다.(tf-idf 기반)
#
# 2. 매개변수
# - num_words
# : 단어 빈도에 따라 유지할 최대 단어 수입니다. 가장 일반적인 단어 만 유지됩니다.
# -filters
# : 각 요소가 텍스트에서 필터링될 문자인 문자열입니다. 기본값은 문자를 제외한 모든 구두점과 탭 및 줄 바꿈 '입니다.
# - lower
# : 부울. 텍스트를 소문자로 변환할지 여부입니다.
# - split
# : str. 단어 분할을 위한 구분 기호입니다.
# - char_level
# : True이면 모든 문자가 토큰으로 처리됩니다.
# - oov_token
# : 주어진 경우, 그것은 word_index에 추가되고 text_to_sequence 호출 중에 어휘 밖의 단어를 대체하는 데 사용됩니다.
#
# 3. 벡터화 과정
# - Tokenizer 인스턴스를 생성
# - fit_on_texts와 word_index를 사용하여 key value로 이루어진 딕셔너리를 생성
# - texts_to_sequences를 이용하여 text 문장을 숫자로 이루어진 리스트로 변경
# - 마지막으로 pad_sequences를 이용하여 리스트의 길이를 통일화

# %%
# Tokenizer 는 데이터에 출현하는 모든 단어의 개수를 세고 빈도 수로 정렬해서 
# num_words 에 지정된 만큼만 숫자로 반환하고, 나머지는 0 으로 반환
tokenizer = Tokenizer(oov_token = "<OOV>")

# %%
# Tokenizer 에 데이터 실제로 입력합니다.
# fit_on_texts와 word_index를 사용하여 key value로 이루어진 딕셔너리를 생성
tokenizer.fit_on_texts(x_train_token)

# %%
# tokenizer의 word_index 속성은 단어와 숫자의 키-값 쌍을 포함하는 딕셔너리를 반환
# 이때, 반환 시 자동으로 소문자로 변환되어 들어가며, 느낌표나 마침표 같은 구두점은 자동으로 제거
# 각 인덱스에 해당하는 단어가 무엇인지 확인
word_to_index  = tokenizer.word_index

# %%
word_to_index
# Out:
# {'<OOV>': 1,
#  '하다': 2,
#  '있다': 3,
#  '되다': 4,
#  '으로': 5,
#  '돋다': 6,
#  '경우': 7,
#  '에서': 8,
#  '시설': 9,
#  '사업': 10,
#  '신청': 11,
#  '관리': 12,
#  '지원': 13,
#  '이다': 14,
#  '또는': 15,
#  '하고': 16,
#  '주택': 17,
#  '센터': 18,
#  '서울시': 19,
#  '운영': 20,
#  '이상': 21,
#  '사항': 22,
#  '교육': 23,
#  '받다': 24,
#  '계획': 25,
#  '업무': 26,
#  '내용': 27,
#  '서울': 28,
#  '이용': 29,
#  '지역': 30,
#  '관련': 31,
#  '따르다': 32,
#  '대상': 33,
#  '확인': 34,
#  '에는': 35,
#  '기준': 36,
#  '해당': 37,
#  '의하다': 38,
#  '규정': 39,
#  '홈페이지': 40,
#  '설치': 41,
#  '건축물': 42,
#  '도시': 43,
#  '제조': 44,
#  '되어다': 45,
#  '없다': 46,
#  '방법': 47,
#  '가능하다': 48,
#  '신고': 49,
#  '변경': 50,
#  '시간': 51,
#  '사용': 52,
#  '주민': 53,
#  '기관': 54,
#  '건축': 55,
#  '상담': 56,
#  '정보': 57,
#  '공무원': 58,
#  '시행': 59,
#  '민원': 60,
#  '위원회': 61,
#  '도로': 62,
#  '건설': 63,
#  '서비스': 64,
#  '등록': 65,
#  '아니다': 66,
#  '기간': 67,
#  '어떻다': 68,
#  '접수': 69,
#  '가능': 70,
#  '않다': 71,
#  '문의': 72,
#  '에게': 73,
#  '토지': 74,
#  '제출': 75,
#  '기술': 76,
#  '기타': 77,
#  '서류': 78,
#  '대한': 79,
#  '무엇': 80,
#  '복지': 81,
#  '처리': 82,
#  '공사': 83,
#  '환경': 84,
#  '포함': 85,
#  '어린이집': 86,
#  '이하': 87,
#  '구역': 88,
#  '보육': 89,
#  '필요하다': 90,
#  '단체': 91,
#  '참여': 92,
#  '발급': 93,
#  '안내': 94,
#  '청소년': 95,
#  '부터': 96,
#  '사회': 97,
#  '면적': 98,
#  '생활': 99,
#  '카드': 100,
#  '구분': 101,
#  '개발': 102,
#  '서울특별시': 103,
#  '구청': 104,
#  '시민': 105,
#  '까지': 106,
#  '지정': 107,
#  '만원': 108,
#  '담당': 109,
#  '문화': 110,
#  '행정': 111,
#  '프로그램': 112,
#  '장애인': 113,
#  '농업': 114,
#  '디자인': 115,
#  '허가': 116,
#  '안전': 117,
#  '전화': 118,
#  '검사': 119,
#  '실시': 120,
#  '주거': 121,
#  '부서': 122,
#  '신청서': 123,
#  '인가요': 124,
#  '이나': 125,
#  '이란': 126,
#  '분양': 127,
#  '자격': 128,
#  '주소': 129,
#  '개요': 130,
#  '제공': 131,
#  '제외': 132,
#  '정비': 133,
#  '니까': 134,
#  '지급': 135,
#  '선정': 136,
#  '추진': 137,
#  '심의': 138,
#  '아파트': 139,
#  '방문': 140,
#  '학교': 141,
#  '종합': 142,
#  '활동': 143,
#  '적용': 144,
#  '보호': 145,
#  '여부': 146,
#  '행위': 147,
#  '의료': 148,
#  '분야': 149,
#  '교통': 150,
#  '다음': 151,
#  '가족': 152,
#  '이내': 153,
#  '개인': 154,
#  '자료': 155,
#  '시스템': 156,
#  '통해': 157,
#  '법률': 158,
#  '목적': 159,
#  '용도': 160,
#  '모집': 161,
#  '미만': 162,
#  '금액': 163,
#  '절차': 164,
#  '발생': 165,
#  '대하': 166,
#  '인정': 167,
#  '대상자': 168,
#  '행사': 169,
#  '장소': 170,
#  '로서': 171,
#  '같다': 172,
#  '하나요': 173,
#  '가입': 174,
#  '제한': 175,
#  '인터넷': 176,
#  '제도': 177,
#  '위해': 178,
#  '작성': 179,
#  '의무': 180,
#  '위치': 181,
#  '정책': 182,
#  '평일': 183,
#  '본인': 184,
#  '소득': 185,
#  '심사': 186,
#  '에서는': 187,
#  '회의': 188,
#  '이며': 189,
#  '범위': 190,
#  '창업': 191,
#  '한국': 192,
#  '계약': 193,
#  '거나': 194,
#  '지구': 195,
#  '시장': 196,
#  '현황': 197,
#  '공간': 198,
#  '결정': 199,
#  '재산': 200,
#  '일반': 201,
#  '체험': 202,
#  '현재': 203,
#  '가스': 204,
#  '거리': 205,
#  '번지': 206,
#  '법인': 207,
#  '건강': 208,
#  '직접': 209,
#  '드리다': 210,
#  '소유자': 211,
#  '결과': 212,
#  '공원': 213,
#  '규모': 214,
#  '구성': 215,
#  '기업': 216,
#  '개선': 217,
#  '이전': 218,
#  '영업': 219,
#  '현장': 220,
#  '임대': 221,
#  '무료': 222,
#  '예산': 223,
#  '주요': 224,
#  '비용': 225,
#  '보증': 226,
#  '보상': 227,
#  '담당자': 228,
#  '제호': 229,
#  '국민': 230,
#  '보다': 231,
#  '증명서': 232,
#  '기본': 233,
#  '우리': 234,
#  '다른': 235,
#  '조례': 236,
#  '공공': 237,
#  '이후': 238,
#  '예정': 239,
#  '부담': 240,
#  '다만': 241,
#  '출구': 242,
#  '직무': 243,
#  '회원': 244,
#  '당하다': 245,
#  '산업': 246,
#  '시청': 247,
#  '공급': 248,
#  '보험': 249,
#  '전화번호': 250,
#  '법령': 251,
#  '공고': 252,
#  '과정': 253,
#  '대표': 254,
#  '가정': 255,
#  '표시': 256,
#  '자동차': 257,
#  '납부': 258,
#  '조합': 259,
#  '관계': 260,
#  '자치': 261,
#  '판매': 262,
#  '일정': 263,
#  '공동': 264,
#  '진행': 265,
#  '감사': 266,
#  '개월': 267,
#  '예약': 268,
#  '업체': 269,
#  '거주': 270,
#  '대해': 271,
#  '으로서': 272,
#  '모든': 273,
#  '여성': 274,
#  '경관': 275,
#  '세대': 276,
#  '아동': 277,
#  '온라인': 278,
#  '국가': 279,
#  '호선': 280,
#  '바라다': 281,
#  '서대문구': 282,
#  '수행': 283,
#  '운동': 284,
#  '재정': 285,
#  '수급': 286,
#  '검색': 287,
#  '급여': 288,
#  '동의': 289,
#  '필요': 290,
#  '기획': 291,
#  '활용': 292,
#  '자치구': 293,
#  '싶다': 294,
#  '홍보': 295,
#  '없이': 296,
#  '가다': 297,
#  '부분': 298,
#  '가구': 299,
#  '조성': 300,
#  '사업자': 301,
#  '평가': 302,
#  '물품': 303,
#  '함께': 304,
#  '번호': 305,
#  '건물': 306,
#  '승인': 307,
#  '어린이': 308,
#  '공개': 309,
#  '청약': 310,
#  '별도': 311,
#  '공단': 312,
#  '취소': 313,
#  '고시': 314,
#  '에너지': 315,
#  '급식': 316,
#  '진료': 317,
#  '이르다': 318,
#  '조사': 319,
#  '구정': 320,
#  '초과': 321,
#  '차량': 322,
#  '이고': 323,
#  '식품': 324,
#  '효율': 325,
#  '금융': 326,
#  '협회': 327,
#  '통보': 328,
#  '기금': 329,
#  '설립': 330,
#  '통합': 331,
#  '이상인': 332,
#  '에도': 333,
#  '조치': 334,
#  '규칙': 335,
#  '기능': 336,
#  '대장': 337,
#  '이행': 338,
#  '산정': 339,
#  '서다': 340,
#  '요청': 341,
#  '위반': 342,
#  '협의': 343,
#  '피해': 344,
#  '시기': 345,
#  '미터': 346,
#  '근무': 347,
#  '직원': 348,
#  '보건': 349,
#  '희망': 350,
#  '결제': 351,
#  '능력': 352,
#  '의거': 353,
#  '기계': 354,
#  '작품': 355,
#  '개정': 356,
#  '개별': 357,
#  '인가': 358,
#  '주거지역': 359,
#  '단위': 360,
#  '촉진': 361,
#  '친환경': 362,
#  '시시': 363,
#  '주민등록': 364,
#  '신용': 365,
#  '반드시': 366,
#  '일시': 367,
#  '연결': 368,
#  '기재': 369,
#  '사례': 370,
#  '구비': 371,
#  '수립': 372,
#  '단지': 373,
#  '자연': 374,
#  '방지': 375,
#  '노인': 376,
#  '문자': 377,
#  '관할': 378,
#  '다양하다': 379,
#  '유지': 380,
#  '높이': 381,
#  '거치다': 382,
#  '부동산': 383,
#  '조회': 384,
#  '인하다': 385,
#  '임신': 386,
#  '억원': 387,
#  '대지': 388,
#  '종류': 389,
#  '감리': 390,
#  '보조금': 391,
#  '인증': 392,
#  '취업': 393,
#  '예방': 394,
#  '자본금': 395,
#  '이메일': 396,
#  '지방': 397,
#  '은평구': 398,
#  '편의': 399,
#  '검토': 400,
#  '설명': 401,
#  '청장': 402,
#  '확보': 403,
#  '요금': 404,
#  '설계': 405,
#  '각종': 406,
#  '제곱미터': 407,
#  '중구': 408,
#  '특정': 409,
#  '재료': 410,
#  '전용': 411,
#  '콜센터': 412,
#  '아래': 413,
#  '자금': 414,
#  '향상': 415,
#  '관심': 416,
#  '지다': 417,
#  '사유': 418,
#  '알다': 419,
#  '사전': 420,
#  '교사': 421,
#  '책임': 422,
#  '대출': 423,
#  '장애': 424,
#  '고객': 425,
#  '대다': 426,
#  '경력': 427,
#  '원칙': 428,
#  '대표자': 429,
#  '경제': 430,
#  '하나': 431,
#  '호의': 432,
#  '청구': 433,
#  '증명': 434,
#  '기존': 435,
#  '사람': 436,
#  '연락처': 437,
#  '전산': 438,
#  '완료': 439,
#  '발송': 440,
#  '설비': 441,
#  '또한': 442,
#  '특별': 443,
#  '장이': 444,
#  '등록증': 445,
#  '명의': 446,
#  '근로': 447,
#  '병원': 448,
#  '학부모': 449,
#  '선택': 450,
#  '기술자': 451,
#  '취득': 452,
#  '가격': 453,
#  '불가': 454,
#  '당직': 455,
#  '의견': 456,
#  '열람': 457,
#  '송파구': 458,
#  '소재': 459,
#  '행동강령': 460,
#  '녹지': 461,
#  '개최': 462,
#  '민간': 463,
#  '점검': 464,
#  '처분': 465,
#  '사본': 466,
#  '우편': 467,
#  '연장': 468,
#  '인원': 469,
#  '자녀': 470,
#  '어디': 471,
#  '지방자치단체': 472,
#  '기초': 473,
#  '시키다': 474,
#  '외부': 475,
#  '의원': 476,
#  '회복': 477,
#  '소유': 478,
#  '수련': 479,
#  '복지관': 480,
#  '공휴일': 481,
#  '우선': 482,
#  '교실': 483,
#  '송파': 484,
#  '입자': 485,
#  '년도': 486,
#  '자세하다': 487,
#  '위원': 488,
#  '다운로드': 489,
#  '일부': 490,
#  '추다': 491,
#  '청사': 492,
#  '근거': 493,
#  '상의': 494,
#  '선발': 495,
#  '주다': 496,
#  '가지': 497,
#  '많다': 498,
#  '참가': 499,
#  '학습': 500,
#  '주체': 501,
#  '형태': 502,
#  '구민': 503,
#  '방송': 504,
#  '임대주택': 505,
#  '전문가': 506,
#  '응모': 507,
#  '참고': 508,
#  '등본': 509,
#  '발전': 510,
#  '별표': 511,
#  '용산구': 512,
#  '빌딩': 513,
#  '조정': 514,
#  '첨부': 515,
#  '으로부터': 516,
#  '방향': 517,
#  '누구': 518,
#  '미술': 519,
#  '주자': 520,
#  '공모': 521,
#  '양식': 522,
#  '발표': 523,
#  '합계': 524,
#  '건축법': 525,
#  '제품': 526,
#  '문서': 527,
#  '광장': 528,
#  '본부': 529,
#  '중계': 530,
#  '방식': 531,
#  '사실': 532,
#  '장관': 533,
#  '시정': 534,
#  '사고': 535,
#  '보고': 536,
#  '사진': 537,
#  '도시농업': 538,
#  '계속': 539,
#  '수수료': 540,
#  '로부터': 541,
#  '유형': 542,
#  '공직자': 543,
#  '부과': 544,
#  '보수': 545,
#  '어르신': 546,
#  '통한': 547,
#  '준비': 548,
#  '수용': 549,
#  '추가': 550,
#  '지하철': 551,
#  '주차장': 552,
#  '소속': 553,
#  '영상': 554,
#  '전문': 555,
#  '마을': 556,
#  '품질': 557,
#  '동물': 558,
#  '별로': 559,
#  '종료': 560,
#  '접속': 561,
#  '일수': 562,
#  '도서관': 563,
#  '아이': 564,
#  '원하다': 565,
#  '소통': 566,
#  '의미': 567,
#  '토요일': 568,
#  '차다': 569,
#  '구조': 570,
#  '어느': 571,
#  '강사': 572,
#  '요구': 573,
#  '시험': 574,
#  '공지': 575,
#  '용적률': 576,
#  '부모': 577,
#  '맞춤': 578,
#  '마련': 579,
#  '수준': 580,
#  '의결': 581,
#  '위생': 582,
#  '게시': 583,
#  '체계': 584,
#  '서초구': 585,
#  '토목': 586,
#  '주제': 587,
#  '소개': 588,
#  '신분증': 589,
#  '정도': 590,
#  '자가': 591,
#  '거부': 592,
#  '지점': 593,
#  '마다': 594,
#  '개다': 595,
#  '치매': 596,
#  '팩스': 597,
#  '대책': 598,
#  '비다': 599,
#  '은평': 600,
#  '상황': 601,
#  '권리': 602,
#  '최고': 603,
#  '위험': 604,
#  '초등학교': 605,
#  '요건': 606,
#  '안심': 607,
#  '바로가기': 608,
#  '집행': 609,
#  '확대': 610,
#  '출산': 611,
#  '학생': 612,
#  '은행': 613,
#  '제안': 614,
#  '모두': 615,
#  '공장': 616,
#  '환경보전': 617,
#  '버스': 618,
#  '제작': 619,
#  '언제': 620,
#  '입력': 621,
#  '통화': 622,
#  '근로자': 623,
#  '늘다': 624,
#  '주의': 625,
#  '으로써': 626,
#  '자동': 627,
#  '상태': 628,
#  '가로': 629,
#  '진흥': 630,
#  '주차': 631,
#  '강의': 632,
#  '경계': 633,
#  '좋다': 634,
#  '활성화': 635,
#  '매년': 636,
#  '부패': 637,
#  '서식': 638,
#  '국토': 639,
#  '운행': 640,
#  '열리다': 641,
#  '상금': 642,
#  '협력': 643,
#  '세부': 644,
#  '구매': 645,
#  '여건': 646,
#  '진단': 647,
#  '투자': 648,
#  '주변': 649,
#  '뉴타운': 650,
#  '철거': 651,
#  '불편': 652,
#  '임원': 653,
#  '적합하다': 654,
#  '공용': 655,
#  '조직': 656,
#  '수강': 657,
#  '사무': 658,
#  '수령': 659,
#  '신용카드': 660,
#  '여행': 661,
#  '폐지': 662,
#  '구입': 663,
#  '한도': 664,
#  '아동복': 665,
#  '운전': 666,
#  '항의': 667,
#  '판단': 668,
#  '사이트': 669,
#  '전달': 670,
#  '배출': 671,
#  '보전': 672,
#  '증빙': 673,
#  '과의': 674,
#  '안되다': 675,
#  '확정': 676,
#  '구축': 677,
#  '교류': 678,
#  '거래': 679,
#  '자활': 680,
#  '주말': 681,
#  '밉다': 682,
#  '최대': 683,
#  '증진': 684,
#  '상봉': 685,
#  '모니터링': 686,
#  '등기': 687,
#  '인재': 688,
#  '매주': 689,
#  '상세': 690,
#  '집회': 691,
#  '체육': 692,
#  '일요일': 693,
#  '금지': 694,
#  '농지': 695,
#  '컴퓨터': 696,
#  '따라서': 697,
#  '통신': 698,
#  '수입': 699,
#  '전체': 700,
#  '중앙': 701,
#  '마당': 702,
#  '보장': 703,
#  '전국': 704,
#  '클릭': 705,
#  '연도': 706,
#  '기반시설': 707,
#  '저축': 708,
#  '천만원': 709,
#  '강화': 710,
#  '후원': 711,
#  '광고': 712,
#  '의처': 713,
#  '인지': 714,
#  '효과': 715,
#  '특성': 716,
#  '관광': 717,
#  '설정': 718,
#  '추천': 719,
#  '점자': 720,
#  '쉬다': 721,
#  '자문': 722,
#  '경로': 723,
#  '허용': 724,
#  '영등포구': 725,
#  '재단': 726,
#  '자다': 727,
#  '일월': 728,
#  '육아': 729,
#  '사랑': 730,
#  '카페': 731,
#  '세대주': 732,
#  '자재': 733,
#  '얻다': 734,
#  '종사': 735,
#  '조건': 736,
#  '동일하다': 737,
#  '나무': 738,
#  '도서': 739,
#  '보건소': 740,
#  '지도': 741,
#  '말다': 742,
#  '만들다': 743,
#  '도보': 744,
#  '순위': 745,
#  '계산': 746,
#  '시도': 747,
#  '구간': 748,
#  '직업': 749,
#  '보증금': 750,
#  '자로': 751,
#  '성과': 752,
#  '기록': 753,
#  '재건축': 754,
#  '고려': 755,
#  '지적': 756,
#  '위임': 757,
#  '연구': 758,
#  '권한': 759,
#  '경영': 760,
#  '전환': 761,
#  '정부': 762,
#  '교육청': 763,
#  '마포구': 764,
#  '일금': 765,
#  '종로구': 766,
#  '조합원': 767,
#  '예금': 768,
#  '보조': 769,
#  '실습': 770,
#  '명령': 771,
#  '인력': 772,
#  '사무소': 773,
#  '시공': 774,
#  '통지': 775,
#  '의뢰': 776,
#  '자체': 777,
#  '갖추다': 778,
#  '소방': 779,
#  '도입': 780,
#  '유아': 781,
#  '영리': 782,
#  '예술': 783,
#  '토록': 784,
#  '포장': 785,
#  '관리자': 786,
#  '석유': 787,
#  '변화': 788,
#  '이라': 789,
#  '자의': 790,
#  '채무': 791,
#  '감사하다': 792,
#  '다시': 793,
#  '계층': 794,
#  '경비': 795,
#  '국제': 796,
#  '돌보다': 797,
#  '컨설팅': 798,
#  '크다': 799,
#  '역할': 800,
#  '전시': 801,
#  '오다': 802,
#  '조명': 803,
#  '매월': 804,
#  '수당': 805,
#  '관내': 806,
#  '발코니': 807,
#  '바닥면적': 808,
#  '성동구': 809,
#  '창의': 810,
#  '규제': 811,
#  '체결': 812,
#  '감독': 813,
#  '밖에': 814,
#  '단독주택': 815,
#  '유사하다': 816,
#  '성북구': 817,
#  '할인': 818,
#  '표준': 819,
#  '참조': 820,
#  '현금': 821,
#  '청년': 822,
#  '공익': 823,
#  '가입자': 824,
#  '정원': 825,
#  '중복': 826,
#  '상위': 827,
#  '지출': 828,
#  '상업': 829,
#  '복합': 830,
#  '도모': 831,
#  '외한': 832,
#  '입소': 833,
#  '보육료': 834,
#  '편하다': 835,
#  '들다': 836,
#  '이름': 837,
#  '명칭': 838,
#  '택법': 839,
#  '회계': 840,
#  '자격증': 841,
#  '광진구': 842,
#  '해주다': 843,
#  '쓰이다': 844,
#  '공업': 845,
#  '깊다': 846,
#  '일자': 847,
#  '장기': 848,
#  '메인': 849,
#  '사용자': 850,
#  '항목': 851,
#  '생산': 852,
#  '이외': 853,
#  '단계': 854,
#  '위원장': 855,
#  '품목': 856,
#  '귀농': 857,
#  '연중': 858,
#  '제시': 859,
#  '시립': 860,
#  '특수': 861,
#  '질환': 862,
#  '터미널': 863,
#  '상징': 864,
#  '공유': 865,
#  '소요': 866,
#  '뉴스': 867,
#  '실적': 868,
#  '주시': 869,
#  '신규': 870,
#  '준공': 871,
#  '노력': 872,
#  '화면': 873,
#  '최초': 874,
#  '공자': 875,
#  '퇴직': 876,
#  '발행': 877,
#  '청원': 878,
#  '우수': 879,
#  '강연': 880,
#  '자립': 881,
#  '상호': 882,
#  '공제': 883,
#  '반납': 884,
#  '봉사': 885,
#  '대회': 886,
#  '중소기업': 887,
#  '안정': 888,
#  '최종': 889,
#  '상환': 890,
#  '중심': 891,
#  '다르다': 892,
#  '측량': 893,
#  '상단': 894,
#  '부여': 895,
#  '찾아가다': 896,
#  '역사': 897,
#  '재개발': 898,
#  '임기': 899,
#  '연락': 900,
#  '변동': 901,
#  '운수': 902,
#  '리포터': 903,
#  '기사': 904,
#  '문제': 905,
#  '보내다': 906,
#  '회사': 907,
#  '일이': 908,
#  '노원구': 909,
#  '서면': 910,
#  '원장': 911,
#  '하자': 912,
#  '공연': 913,
#  '재결': 914,
#  '가액': 915,
#  '국가기술자격법': 916,
#  '대리인': 917,
#  '강남구': 918,
#  '장비': 919,
#  '행정처분': 920,
#  '중랑구': 921,
#  '자유': 922,
#  '사비': 923,
#  '정관': 924,
#  '창구': 925,
#  '결재': 926,
#  '물류': 927,
#  '회관': 928,
#  '업다': 929,
#  '저장': 930,
#  '재배': 931,
#  '절약': 932,
#  '전자': 933,
#  '방안': 934,
#  '노선': 935,
#  '최근': 936,
#  '생계': 937,
#  '우리은행': 938,
#  '총회': 939,
#  '가장': 940,
#  '위탁': 941,
#  '광역시': 942,
#  '동일': 943,
#  '이익': 944,
#  '메일': 945,
#  '교복': 946,
#  '부지': 947,
#  '여행사': 948,
#  '면허': 949,
#  '일화': 950,
#  '업종': 951,
#  '등급': 952,
#  '점포': 953,
#  '개인정보': 954,
#  '여론조사': 955,
#  '지하': 956,
#  '영농': 957,
#  '교부': 958,
#  '계좌': 959,
#  '지침': 960,
#  '직장': 961,
#  '오전': 962,
#  '오후': 963,
#  '협조': 964,
#  '작업': 965,
#  '이야기': 966,
#  '대로': 967,
#  '건립': 968,
#  '구체': 969,
#  '외국인': 970,
#  '위촉': 971,
#  '도봉구': 972,
#  '발간': 973,
#  '영어': 974,
#  '이자': 975,
#  '금품': 976,
#  '안전하다': 977,
#  '의사': 978,
#  '유도': 979,
#  '장기기증': 980,
#  '어디서': 981,
#  '최소': 982,
#  '확인가능': 983,
#  '유치원': 984,
#  '통계': 985,
#  '로그인': 986,
#  '편리하다': 987,
#  '역서': 988,
#  '사망': 989,
#  '국토교통부': 990,
#  '산모': 991,
#  '농협': 992,
#  '이동': 993,
#  '수상': 994,
#  '연결하다': 995,
#  '보일러': 996,
#  '특별활동': 997,
#  '지킴': 998,
#  '물의': 999,
#  '두다': 1000,
#  ...}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('안전', 150),
#              ('관리', 570),
#              ('계획', 451),
#              ('대상', 370),
#              ('건설', 259),
#              ('기술', 216),
#              ('아래', 52),
#              ('같다', 110),
#              ('시특법', 1),
#              ('규정', 332),
#              ('의하다', 333),
#              ('시설', 901),
#              ('물의', 21),
#              ('공사', 191),
#              ('지하', 22),
#              ('굴착', 6),
#              ('이상', 476),
#              ('미만', 114),
#              ('건축물', 324),
#              ('또는', 546),
#              ('모델링', 7),
#              ('해체', 6),
#              ('사업', 875),
#              ('조정제', 1),
#              ('도란', 12),
#              ('대기업', 1),
#              ('진출', 3),
#              ('중소기업', 24),
#              ('안정', 24),
#              ('현저', 9),
#              ('하다', 5510),
#              ('영향', 14),
#              ('미치다', 9),
#              ('우려', 20),
#              ('있다', 1814),
#              ('경우', 934),
#              ('일정', 76),
#              ('기간', 255),
#              ('인수', 4),
#              ('개시', 12),
#              ('확장', 13),
#              ('연기', 1),
#              ('거나', 101),
#              ('축소', 2),
#              ('권고', 9),
#              ('제도', 108),
#              ('조정', 41),
#              ('신청', 611),
#              ('절차', 113),
#              ('단체', 174),
#              ('이내', 120),
#              ('종업', 4),
#              ('동의', 71),
#              ('얻다', 29),
#              ('중앙회', 6),
#              ('심의회', 5),
#              ('최종', 24),
#              ('이행', 62),
#              ('명령', 28),
#              ('밉다', 31),
#              ('행시', 4),
#              ('제재', 4),
#              ('수단', 13),
#              ('늘다', 34),
#              ('실태', 12),
#              ('응시', 6),
#              ('이하', 184),
#              ('징역', 7),
#              ('천만원', 30),
#              ('벌금', 12),
#              ('조산', 7),
#              ('기준', 348),
#              ('입원', 14),
#              ('이용', 401),
#              ('실조', 1),
#              ('제실', 1),
#              ('두다', 21),
#              ('소독', 6),
#              ('귀농', 25),
#              ('농업', 155),
#              ('창업', 103),
#              ('주택', 522),
#              ('구입', 32),
#              ('어떻다', 255),
#              ('하나요', 110),
#              ('지원', 564),
#              ('이후', 83),
#              ('도시', 323),
#              ('에서', 909),
#              ('거주', 75),
#              ('전업', 2),
#              ('으로', 1326),
#              ('위해', 107),
#              ('가족', 122),
#              ('농촌', 15),
#              ('지역', 401),
#              ('이주하', 4),
#              ('영농', 22),
#              ('종사', 29),
#              ('하고', 546),
#              ('조건', 29),
#              ('세대', 74),
#              ('한도', 32),
#              ('거치', 15),
#              ('균등', 4),
#              ('상환', 24),
#              ('자금', 52),
#              ('최대', 31),
#              ('억원', 56),
#              ('까지', 161),
#              ('방법', 303),
#              ('정착', 16),
#              ('주소지', 9),
#              ('관할', 57),
#              ('면사무소', 1),
#              ('센터', 507),
#              ('나우', 1),
#              ('스타트', 2),
#              ('업무', 430),
#              ('개요', 137),
#              ('새롭다', 19),
#              ('교육', 457),
#              ('복지', 203),
#              ('기회', 15),
#              ('지금', 4),
#              ('제공', 136),
#              ('경쟁력', 6),
#              ('되다', 1633),
#              ('현실', 7),
#              ('부모', 37),
#              ('보호', 127),
#              ('받다', 453),
#              ('필요', 71),
#              ('아동', 74),
#              ('에게', 229),
#              ('맞춤', 37),
#              ('학습', 42),
#              ('서비스', 259),
#              ('기초', 45),
#              ('능력', 60),
#              ('향상', 52),
#              ('통한', 39),
#              ('강화', 30),
#              ('출발', 11),
#              ('도와주다', 3),
#              ('내용', 426),
#              ('소득', 105),
#              ('가정', 77),
#              ('평등하다', 2),
#              ('환경', 190),
#              ('마련', 37),
#              ('의식주', 1),
#              ('수동', 5),
#              ('나아가다', 7),
#              ('일반', 95),
#              ('아이', 38),
#              ('동일하다', 29),
#              ('수준별', 4),
#              ('성적', 11),
#              ('사교육', 3),
#              ('비용', 87),
#              ('참여', 174),
#              ('차이', 11),
#              ('심각', 1),
#              ('높다', 19),
#              ('일수록', 1),
#              ('교육비', 12),
#              ('증가', 12),
#              ('학생', 35),
#              ('수준', 37),
#              ('지출', 26),
#              ('상관관계', 1),
#              ('대한', 211),
#              ('특기', 2),
#              ('증진', 31),
#              ('상대', 5),
#              ('부족하다', 9),
#              ('실정', 2),
#              ('양육', 10),
#              ('공동', 76),
#              ('생활', 166),
#              ('가정위탁', 2),
#              ('학력', 9),
#              ('기별', 5),
#              ('원금', 21),
#              ('후원', 30),
#              ('학원', 11),
#              ('사회자', 4),
#              ('자원봉사자', 11),
#              ('온라인교육', 1),
#              ('주체', 42),
#              ('아동복', 32),
#              ('중심', 24),
#              ('수행', 72),
#              ('인력', 28),
#              ('명사회', 1),
#              ('복지사', 6),
#              ('임상심리사', 1),
#              ('나무', 29),
#              ('서포터', 2),
#              ('역할', 27),
#              ('사회', 168),
#              ('자원', 14),
#              ('매니저', 1),
#              ('다양하다', 57),
#              ('프로그램', 156),
#              ('개설', 17),
#              ('드림', 7),
#              ('기타', 216),
#              ('방과후', 13),
#              ('부방', 21),
#              ('급식', 66),
#              ('사례', 58),
#              ('문화', 159),
#              ('추진', 134),
#              ('심리상담', 4),
#              ('상담', 269),
#              ('심리치료', 6),
#              ('등꿈', 1),
#              ('청소년', 170),
#              ('수련', 44),
#              ('종합', 131),
#              ('복지관', 44),
#              ('매니지먼트', 1),
#              ('사항', 459),
#              ('새마을금고', 17),
#              ('창립총회', 4),
#              ('의결', 37),
#              ('발기인', 3),
#              ('금고', 11),
#              ('설립', 63),
#              ('제출', 221),
#              ('과반수', 18),
#              ('출석', 18),
#              ('찬성', 4),
#              ('전략', 11),
#              ('이란', 139),
#              ('무엇', 204),
#              ('니까', 135),
#              ('기획', 71),
#              ('선도', 4),
#              ('주의', 34),
#              ('관점', 6),
#              ('바라보다', 4),
#              ('장단', 3),
#              ('목표', 13),
#              ('선택', 47),
#              ('관심', 52),
#              ('갖다', 7),
#              ('형태', 42),
#              ('상봉', 31),
#              ('존치', 9),
#              ('구역', 184),
#              ('돋다', 1250),
#              ('지다', 52),
#              ('상업', 26),
#              ('순수', 6),
#              ('으로만', 5),
#              ('건축', 272),
#              ('없다', 318),
#              ('주상', 3),
#              ('복합', 26),
#              ('에는', 357),
#              ('가능하다', 297),
#              ('용도지역', 20),
#              ('이다', 555),
#              ('허가', 151),
#              ('사용승인', 18),
#              ('까지의', 15),
#              ('문의', 239),
#              ('먼저', 19),
#              ('고객', 50),
#              ('께서', 12),
#              ('대지', 56),
#              ('지구', 101),
#              ('따르다', 374),
#              ('제한', 109),
#              ('종류', 56),
#              ('규모', 91),
#              ('다소', 4),
#              ('다르다', 24),
#              ('알다', 51),
#              ('드리다', 93),
#              ('건축사', 16),
#              ('사무소', 28),
#              ('도움', 17),
#              ('대신', 14),
#              ('필요하다', 177),
#              ('서류', 214),
#              ('관련', 400),
#              ('설계', 53),
#              ('도서', 29),
#              ('준비', 39),
#              ('줄다', 5),
#              ('이고', 64),
#              ('작성', 107),
#              ('신청서', 142),
#              ('구비', 58),
#              ('접수', 252),
#              ('부터는', 7),
#              ('담당자', 86),
#              ('검토', 54),
#              ('부서', 143),
#              ('기관', 275),
#              ('협의', 61),
#              ('법령', 78),
#              ('회신', 1),
#              ('완료', 48),
#              ('교부', 22),
#              ('착공', 13),
#              ('고서', 4),
#              ('신고', 292),
#              ('출시', 9),
#              ('각종', 53),
#              ('계약서', 21),
#              ('설계자', 7),
#              ('감리', 56),
#              ('시공', 28),
#              ('사본', 46),
#              ('가설', 7),
#              ('설치', 326),
#              ('변경', 292),
#              ('반영', 19),
#              ('초등학생', 6),
#              ('틀다', 6),
#              ('건강', 94),
#              ('프로젝트', 6),
#              ('체험', 95),
#              ('홍보', 70),
#              ('운영', 489),
#              ('올바르다', 8),
#              ('정보', 269),
#              ('공함', 4),
#              ('으로써', 34),
#              ('건강하다', 19),
#              ('습관', 6),
#              ('형성', 12),
#              ('시키다', 45),
#              ('성장', 16),
#              ('발달', 7),
#              ('도모', 26),
#              ('연중', 25),
#              ('학교', 132),
#              ('지정', 161),
#              ('장소', 111),
#              ('강당', 5),
#              ('체육관', 3),
#              ('대다', 50),
#              ('고등학교', 17),
#              ('보건소', 29),
#              ('개팀', 7),
#              ('협력', 33),
#              ('식품위생', 5),
#              ('식품', 64),
#              ('진료', 66),
#              ('부스', 6),
#              ('순회', 2),
#              ('체험학습', 7),
#              ('축제', 7),
#              ('세부', 33),
#              ('영양', 9),
#              ('비만', 6),
#              ('열량', 2),
#              ('모형', 6),
#              ('전시', 27),
#              ('설명', 54),
#              ('구성', 91),
#              ('도전', 2),
#              ('게임', 5),
#              ('진행', 76),
#              ('조끼', 2),
#              ('예방', 55),
#              ('운동', 72),
#              ('체지방', 1),
#              ('측정', 8),
#              ('개인', 118),
#              ('지도', 29),
#              ('바르다', 4),
#              ('자세', 3),
#              ('유지', 57),
#              ('연관', 1),
#              ('흡연', 3),
#              ('비교', 21),
#              ('간접흡연', 1),
#              ('피해', 61),
#              ('일산화탄소', 1),
#              ('금연', 2),
#              ('담배', 8),
#              ('타르모', 1),
#              ('치아', 2),
#              ('피다', 7),
#              ('스모키', 1),
#              ('앞치마', 1),
#              ('보드', 10),
#              ('주관', 18),
#              ('투호', 1),
#              ('고글', 2),
#              ('활용', 71),
#              ('가상', 3),
#              ('음주', 4),
#              ('아토피', 1),
#              ('천식', 2),
#              ('아토피피부염', 1),
#              ('치료', 18),
#              ('피부관리', 1),
#              ('원인', 15),
#              ('구강', 7),
#              ('위상', 3),
#              ('현미경', 1),
#              ('세균', 1),
#              ('관찰', 10),
#              ('잇솔질', 3),
#              ('점심식사', 3),
#              ('칫솔질', 1),
#              ('코너', 12),
#              ('착색', 1),
#              ('발색', 1),
#              ('실험', 2),
#              ('양표', 1),
#              ('시제', 1),
#              ('안내', 171),
#              ('위생', 37),
#              ('감시', 3),
#              ('모니터링', 31),
#              ('기구', 16),
#              ('손씻기', 1),
#              ('부정', 9),
#              ('불량', 9),
#              ('포스터', 1),
#              ('판넬', 4),
#              ('배너', 7),
#              ('홍보물', 9),
#              ('리플릿', 1),
#              ('배부', 6),
#              ('자본금', 55),
#              ('조경분', 3),
#              ('기술자', 47),
#              ('국가기술자격법', 23),
#              ('종목', 20),
#              ('자격', 138),
#              ('취득', 47),
#              ('일상', 16),
#              ('감사', 76),
#              ('에의', 7),
#              ('적합', 3),
#              ('가격', 47),
#              ('산출', 18),
#              ('결정', 97),
#              ('적정', 14),
#              ('여부', 126),
#              ('설계도', 3),
#              ('시방서', 4),
#              ('목적', 115),
#              ('과업', 1),
#              ('지시', 17),
#              ('물품', 69),
#              ('구매', 33),
#              ('필요성', 8),
#              ('시기', 61),
#              ('무허가', 11),
#              ('건물', 68),
#              ('지번', 8),
#              ('정정', 12),
#              ('측량', 24),
#              ('과도', 11),
#              ('대리인', 23),
#              ('위임장', 10),
#              ('인감증명서', 12),
#              ('첨부', 41),
#              ('소유자', 93),
#              ('어린이집', 187),
#              ('소시', 1),
#              ('환불', 11),
#              ('적용', 128),
#              ('소결', 1),
#              ('제시', 25),
#              ('부담', 81),
#              ('반환받다', 2),
#              ('금액', 114),
#              ('환급', 3),
#              ('프로세스', 1),
#              ('계좌', 22),
#              ('입금', 19),
#              ('시스템', 116),
#              ('자동', 34),
#              ('정산', 10),
#              ('해당', 348),
#              ('통지', 28),
#              ('드릴', 4),
#              ('예정', 83),
#              ('비례', 4),
#              ('제어', 4),
#              ('운전', 32),
#              ('기기', 16),
#              ('출력', 7),
#              ('편차', 1),
#              ('입력량', 1),
#              ('조절', 3),
#              ('최적', 3),
#              ('상태', 34),
#              ('방식', 40),
#              ('서울특별시', 164),
#              ('장애인인권', 2),
#              ('장애인', 156),
#              ('인권', 16),
#              ('침해', 14),
#              ('차별', 8),
#              ('행위', 126),
#              ('통해', 116),
#              ('완전하다', 2),
#              ('통합', 63),
#              ('구분', 165),
#              ('전화', 150),
#              ('전화번호', 79),
#              ('시간', 286),
#              ('평일', 106),
#              ('공휴일', 44),
#              ('휴무', 16),
#              ('점심시간', 7),
#              ('시시', 59),
#              ('불가', 47),
#              ('홈페이지', 328),
#              ('옹호', 1),
#              ('주소', 138),
#              ('서울시', 496),
#              ('강남구', 23),
#              ('도곡로', 1),
#              ('서울', 420),
#              ('시립', 25),
#              ('행복플러스', 1),
#              ('학대', 6),
#              ('온라인', 74),
#              ('이메일', 55),
#              ('팩스', 36),
#              ('우편', 46),
#              ('소규모', 8),
#              ('초등', 6),
#              ('중등', 6),
#              ('특수', 25),
#              ('전문직', 1),
#              ('공무원', 268),
#              ('의무', 107),
#              ('시민', 162),
#              ('대책', 36),
#              ('여름철', 3),
#              ('개월', 76),
#              ('겨울철', 4),
#              ('설날', 3),
#              ('전후', 11),
#              ('추석', 9),
#              ('배치', 19),
#              ('산업', 80),
#              ('기본', 85),
#              ('제조', 321),
#              ('시행', 268),
#              ('의거', 60),
#              ('경력', 50),
#              ('정해지다', 5),
#              ('연장', 46),
#              ('승인', 68),
#              ('몇번', 2),
#              ('희귀', 3),
#              ('난치', 3),
#              ('질환', 25),
#              ('번일', 3),
#              ('외대', 2),
#              ('심사', 105),
#              ('담당', 160),
#              ('관실', 3),
#              ('계약', 102),
#              ('상급', 7),
#              ('조달청', 6),
#              ('의뢰', 28),
#              ('발주', 9),
#              ('용역', 21),
#              ('청장', 54),
#              ('비다', 36),
#              ('책정', 7),
#              ('행정자치부', 13),
#              ('지침', 22),
#              ('검사', 148),
#              ('광고', 30),
#              ('옥상', 8),
#              ('간판', 16),
#              ('다만', 81),
#              ('바닥', 21),
#              ('으로부터의', 4),
#              ('높이', 57),
#              ('미터', 61),
#              ('볼링', 1),
#              ('게시', 37),
#              ('없이', 70),
#              ('조물', 13),
#              ('직접', 94),
#              ('도료', 1),
#              ('입체', 10),
#              ('표시', 77),
#              ('외한', 26),
#              ('상단', 24),
#              ('지면', 5),
#              ('으로부터', 41),
#              ('면적', 168),
#              ('제곱미터', 53),
#              ('이상인', 63),
#              ('돌출', 6),
#              ('가로', 34),
#              ('길이', 4),
#              ('항의', 32),
#              ('애드벌룬', 2),
#              ('위치', 107),
#              ('공중', 6),
#              ('조례', 84),
#              ('제호', 86),
#              ('내지', 10),
#              ('의료', 125),
#              ('실의', 5),
#              ('규격', 17),
#              ('사실', 40),
#              ('자체', 28),
#              ('장비', 23),
#              ('갖추다', 28),
#              ('야하다', 14),
#              ('근저당권', 14),
#              ('말소등기', 2),
#              ('말다', 29),
#              ('등기', 31),
#              ('당사자', 13),
#              ('일방', 2),
#              ('의사표시', 3),
#              ('해지', 10),
#              ('당직', 47),
#              ('무시', 5),
#              ('여직원', 2),
#              ('근무', 61),
#              ('아니다', 257),
#              ('청사', 43),
#              ('여건', 33),
#              ('일직', 3),
#              ('구청', 163),
#              ('직위', 21),
#              ('직급', 9),
#              ('체계', 37),
#              ('시청', 80),
#              ('시장', 99),
#              ('장관', 40),
#              ('부시장', 5),
#              ('차관', 8),
#              ('본부장', 5),
#              ('상당', 9),
#              ('국장', 20),
#              ('사관', 6),
#              ('부다', 10),
#              ('과장', 16),
#              ('사무관', 4),
#              ('주사', 3),
#              ('사보', 3),
#              ('서기', 3),
#              ('기보', 2),
#              ('외부', 45),
#              ('유출', 4),
#              ('만들다', 29),
#              ('때문', 21),
#              ('통칭', 1),
#              ('주무관', 7),
#              ('말함', 6),
#              ('인재', 31),
#              ('개발', 165),
#              ('개원', 3),
#              ('의처', 30),
#              ('서초구', 37),
#              ('남부', 17),
#              ('순환로', 6),
#              ('서초동', 7),
#              ('터미널', 25),
#              ('출구', 81),
#              ('우회', 6),
#              ('삼거리', 5),
#              ('방향', 41),
#              ('도보', 29),
#              ('소방', 28),
#              ('진입', 17),
#              ('수용', 39),
#              ('인원', 46),
#              ('자녀', 46),
#              ('서초', 8),
#              ('구민', 42),
#              ('보육', 183),
#              ('생후', 2),
#              ('만세', 17),
#              ('입소', 26),
#              ('순위', 29),
#              ('직장', 22),
#              ('직장인', 4),
#              ('우선', 44),
#              ('데이터', 9),
#              ('연구원', 19),
#              ('시정', 40),
#              ('직원', 61),
#              ('서울시공무원', 2),
#              ('포털', 21),
#              ('에도', 63),
#              ('순서', 6),
#              ('우선하다', 2),
#              ('종일', 14),
#              ('사전', 51),
#              ('추가', 39),
#              ('가능', 249),
#              ('보육료', 26),
#              ('별도', 67),
#              ('징수', 18),
#              ('오전', 22),
#              ('교사', 51),
#              ('시간제', 5),
#              ('견학', 6),
#              ('사전예약', 10),
#              ('예약', 76),
#              ('공문', 13),
#              ('발송', 48),
#              ('매주', 31),
#              ('수요일', 11),
#              ('오후', 22),
#              ('밀도', 8),
#              ('측정기', 3),
#              ('사용', 278),
#              ('골다공증', 1),
#              ('초음파', 5),
#              ('엑스선', 2),
#              ('발생', 113),
#              ('나뉘다', 2),
#              ('진단', 33),
#              ('방사선', 2),
#              ('장치', 12),
#              ('포함', 189),
#              ('일전', 11),
#              ('치가', 7),
#              ('않다', 245),
#              ('하수도', 5),
#              ('설비', 48),
#              ('토목', 37),
#              ('기계', 60),
#              ('분야', 125),
#              ('진흥', 34),
#              ('메이드', 3),
#              ('감성', 3),
#              ('담다', 21),
#              ('경험', 14),
#              ('만들어지다', 3),
#              ('라이프스타일', 1),
#              ('플랫폼', 3),
#              ('브랜드', 13),
#              ('세계', 9),
#              ('함께', 69),
#              ('쓰다', 8),
#              ('기업', 91),
#              ('협업', 2),
#              ('상품', 19),
#              ('발굴', 11),
#              ('원하다', 38),
#              ('상세', 31),
#              ('문의사항', 15),
#              ('브랜드전략', 1),
#              ('공가', 4),
#              ('국민', 86),
#              ('국가', 74),
#              ('협조', 22),
#              ('부여', 24),
#              ('휴가', 21),
#              ('거푸집', 1),
#              ('동바리', 1),
#              ('설치다', 14),
#              ('무게', 3),
#              ('계산', 29),
#              ('적정하다', 14),
#              ('콘크리트', 6),
#              ('중량', 7),
#              ('철근', 1),
#              ('호퍼', 1),
#              ('서술', 1),
#              ('작업', 22),
#              ('지방', 55),
#              ('재정', 72),
#              ('투자', 33),
#              ('인가요', 142),
#              ('예산', 88),
#              ('편성', 16),
#              ('타당성', 7),
#              ('효율', 64),
#              ('미리', 12),
#              ('제도로', 12),
#              ('우리', 85),
#              ('에서는', 105),
#              ('대하', 113),
#              ('위원회', 266),
#              ('심의', 133),
#              ('거치다', 57),
#              ('혹은', 9),
#              ('안경', 2),
#              ('소가', 3),
#              ('과대', 1),
#              ('행정처분', 23),
#              ('영업정지', 8),
#              ('신내동', 3),
#              ('상징', 25),
#              ('조형', 18),
#              ('어디', 46),
#              ('건가', 7),
#              ('중랑구', 23),
#              ('필지', 21),
#              ('신내', 3),
#              ('램프', 3),
#              ('내부', 21),
#              ('작품', 60),
#              ('행꽃채', 2),
#              ('행복', 12),
#              ('꽃잎', 2),
#              ('채우다', 7),
#              ('가다', 70),
#              ('물이', 8),
#              ('오다', 27),
#              ('되어다', 319),
#              ('소통', 38),
#              ('안녕', 4),
#              ('의미', 38),
#              ('봉수대', 6),
#              ('모티브', 2),
#              ('구상', 2),
#              ('배꽃', 2),
#              ('패턴', 6),
#              ('화하다', 10),
#              ('장식', 6),
#              ('야간', 18),
#              ('조명', 27),
#              ('구름', 2),
#              ('연상', 3),
#              ('분수', 2),
#              ('연출', 4),
#              ('절기', 3),
#              ('제외', 136),
#              ('발언', 17),
#              ('찾아가다', 24),
#              ('영국', 5),
#              ('런던', 2),
#              ('이드', 1),
#              ('파크', 3),
#              ('스피커', 1),
#              ('처럼', 6),
#              ('누구', 41),
#              ('주제', 37),
#              ('상관없다', 3),
#              ('자신', 14),
#              ('이야기', 22),
#              ('자유롭다', 17),
#              ('이용대', 12),
#              ('원칙', 50),
#              ('시도', 29),
#              ('그동안', 2),
#              ('야외', 13),
#              ('기후', 2),
#              ('주변', 33),
#              ('소음', 14),
#              ('의견', 47),
#              ('맘껏', 1),
#              ('펼치다', 3),
#              ('다른', 85),
#              ('편하다', 26),
#              ('들다', 26),
#              ('보완', 10),
#              ('목소리', 2),
#              ('개관', 12),
#              ('매일', 7),
#              ('월요일', 12),
#              ('상시', 9),
#              ('하층', 14),
#              ('현장', 89),
#              ('불다', 8),
#              ('자유', 23),
#              ('애환', 2),
#              ('공공', 84),
#              ('이슈', 6),
#              ('비방', 6),
#              ('이나', 141),
#              ('욕설', 4),
#              ('유언비어', 1),
#              ('질서', 9),
#              ('위배', 8),
#              ('매월', 27),
#              ('주제가', 1),
#              ('만일', 4),
#              ('라면', 8),
#              ('녹화', 4),
#              ('매체', 15),
#              ('공유', 25),
#              ('정운영', 6),
#              ('타인', 21),
#              ('마이크', 7),
#              ('가이드라인', 14),
#              ('제정', 13),
#              ('부터', 170),
#              ('횟수', 3),
#              ('회로', 5),
#              ('집회', 31),
#              ('모임', 14),
#              ('용도', 115),
#              ('교통', 125),
#              ('중구', 53),
#              ('세종', 10),
#              ('대로', 22),
#              ('태평로', 4),
#              ('지하철', 39),
#              ('호선', 74),
#              ('시청역', 4),
#              ('주차', 34),
#              ('소면', 1),
#              ('대중교통', 12),
#              ('서소문', 16),
#              ('별관', 10),
#              ('공영', 4),
#              ('주차장', 39),
#              ('대가', 16),
#              ('수당', 27),
#              ('강의', 34),
#              ('회의', 105),
#              ('대상자', 112),
#              ('고대', 17),
#              ('경조사', 7),
#              ('직무', 81),
#              ('친족', 4),
#              ('소속', 39),
#              ('유무', 8),
#              ('불문', 9),
#              ('종교', 18),
#              ('친목단체', 1),
#              ('회원', 81),
#              ('특정', 53),
#              ('다수', 11),
#              ('상대로', 4),
#              ('신문', 11),
#              ('방송', 42),
#              ('현재', 95),
#              ('과거', 9),
#              ('통신망', 1),
#              ('인트라넷', 1),
#              ('나가다', 16),
#              ('열람', 47),
#              ('게재', 14),
#              ('은평', 36),
#              ('뉴타운', 33),
#              ('광역', 14),
#              ('외곽순환', 1),
#              ('도로', 264),
#              ('북부', 5),
#              ('구간', 29),
#              ('일산', 2),
#              ('퇴계원', 1),
#              ('자유로', 1),
#              ('고양시', 5),
#              ('관내', 27),
#              ('국도', 9),
#              ('대체', 7),
#              ('로토', 1),
#              ('당원', 1),
#              ('장흥', 1),
#              ('송추', 1),
#              ('서오릉', 2),
#              ('향후', 13),
#              ('개선', 91),
#              ('사장', 9),
#              ('조치', 63),
#              ('사고', 40),
#              ('활동', 130),
#              ('마포', 20),
#              ('발코니', 27),
#              ('부분', 70),
#              ('샷시', 1),
#              ('자치구', 71),
#              ('베란다', 18),
#              ('바닥면적', 27),
#              ('샤시', 1),
#              ('지붕', 12),
#              ('씌우다', 4),
#              ('인정', 113),
#              ('산정', 62),
#              ('증축', 19),
#              ('또한', 48),
#              ('일조권', 1),
#              ('사선', 2),
#              ('저촉', 5),
#              ('그리고', 14),
#              ('거실', 11),
#              ('방과', 16),
#              ('경계', 34),
#              ('창호', 2),
#              ('등를', 3),
#              ('철거', 33),
#              ('방로', 1),
#              ('무단', 8),
#              ('문화센터', 3),
#              ('건립', 22),
#              ('인근', 13),
#              ('주민', 276),
#              ...])

# %%
total_cnt = len(tokenizer.word_index)
total_cnt
# Out:
# 10026

# %%
# 단어별 빈도수를 확인
threshold = 2
total_cnt = len(tokenizer.word_index)
rare_cnt = 0
total_freq = 0
rare_freq = 0

for key, value in tokenizer.word_counts.items():
    total_freq += value
    if value < threshold:
        rare_cnt += 1
        rare_freq += value

# %%
print("단어 집합의 크기: ", total_cnt)
print("등장 빈도가 %d번 이하인 희귀 단어의 수: %d" % (threshold-1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt) * 100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율: ", (rare_freq / total_freq) * 100)
# Out:
# 단어 집합의 크기:  10026
# 등장 빈도가 1번 이하인 희귀 단어의 수: 3935
# 단어 집합에서 희귀 단어의 비율: 39.247955316177936
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율:  3.2002797703280796

# %%
10026 - 3935
# Out:
# 6091

# %%
tokenizer = Tokenizer(oov_token = "<OOV>", num_words = 6000)

# %%
tokenizer.fit_on_texts(x_train_token)

# %%
# texts_to_sequences를 이용하여 text 문장을 숫자로 이루어진 리스트로 변경
x_train_seq = tokenizer.texts_to_sequences(x_train_token)
x_test_seq = tokenizer.texts_to_sequences(x_test_token)

# %% [markdown]
# ## 패딩(Padding)

# %%
lengths = np.array([len(x) for x in x_train_seq])

# %%
print(np.mean(lengths), np.min(lengths), np.median(lengths), np.max(lengths))
# Out:
# 71.90526315789474 3 40.0 2369

# %%
np.quantile(lengths, [0.25, 0.5, 0.75, 0.9])
# Out:
# array([ 22.,  40.,  78., 160.])

# %%
# 독립변수를 전처리합니다. 
# 문장의 길이가 제각각인 벡터의 크기를 패딩 작업을 통해 나머지 빈 공간을 0으로 채움
# max_length는 패딩의 기준이 됨

x_train_seq = pad_sequences(x_train_seq, truncating = "post", maxlen = 160)
x_test_seq = pad_sequences(x_test_seq, truncating = "post", maxlen = 160)

# %%
x_train_seq.shape, x_test_seq.shape
# Out:
# ((1710, 160), (428, 160))

# %% [markdown]
# ## 모델 만들기

# %%
model = keras.Sequential()

# %%
model.add(keras.layers.Embedding(6000, 128, input_shape = (160,)))
model.add(keras.layers.Bidirectional(keras.layers.LSTM(64, return_sequences = True, dropout = 0.2)))
model.add(keras.layers.Bidirectional(keras.layers.LSTM(32, dropout = 0.2)))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(16, activation = "relu"))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(3, activation = "softmax"))

# %% [markdown]
# ## 모델 컴파일

# %%
# 여러개 정답 중 하나 맞추는 문제이며, 정답값이 one-hot 형태이기 때문에
# 손실 함수는 categorical_crossentropy를 사용
opt = keras.optimizers.Adam(learning_rate = 0.0005)
model.compile(loss = "categorical_crossentropy", optimizer = opt, metrics = ["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 160, 128)          768000
#
#  bidirectional_8 (Bidirectio  (None, 160, 128)         98816
#  nal)
#
#  bidirectional_9 (Bidirectio  (None, 64)               41216
#  nal)
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 16)                1040
#
#  dropout_9 (Dropout)         (None, 16)                0
#
#  dense_9 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 909,123
# Trainable params: 909,123
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = keras.callbacks.EarlyStopping(patience = 8, restore_best_weights=True)

# %% [markdown]
# ## 학습

# %%
# 모델 학습을 실행
history = model.fit(x_train_seq, y_train, epochs = 100, batch_size = 64, callbacks = [es],
                    validation_split = 0.2)
# Out:
# Epoch 1/100
# 22/22 [==============================] - 5s 71ms/step - loss: 1.0351 - accuracy: 0.4905 - val_loss: 0.9439 - val_accuracy: 0.5175
# Epoch 2/100
# 22/22 [==============================] - 1s 31ms/step - loss: 0.9358 - accuracy: 0.5190 - val_loss: 0.8771 - val_accuracy: 0.5556
# Epoch 3/100
# 22/22 [==============================] - 1s 30ms/step - loss: 0.8383 - accuracy: 0.6360 - val_loss: 0.7468 - val_accuracy: 0.6930
# Epoch 4/100
# 22/22 [==============================] - 1s 31ms/step - loss: 0.5892 - accuracy: 0.7690 - val_loss: 0.6207 - val_accuracy: 0.7602
# Epoch 5/100
# 22/22 [==============================] - 1s 44ms/step - loss: 0.4417 - accuracy: 0.8465 - val_loss: 0.5989 - val_accuracy: 0.7544
# Epoch 6/100
# 22/22 [==============================] - 1s 30ms/step - loss: 0.3067 - accuracy: 0.8852 - val_loss: 0.5726 - val_accuracy: 0.7836
# Epoch 7/100
# 22/22 [==============================] - 1s 31ms/step - loss: 0.2442 - accuracy: 0.9167 - val_loss: 0.5618 - val_accuracy: 0.8158
# Epoch 8/100
# 22/22 [==============================] - 1s 30ms/step - loss: 0.1796 - accuracy: 0.9613 - val_loss: 0.5938 - val_accuracy: 0.8070
# Epoch 9/100
# 22/22 [==============================] - 1s 31ms/step - loss: 0.1312 - accuracy: 0.9744 - val_loss: 0.6630 - val_accuracy: 0.8041
# Epoch 10/100
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0976 - accuracy: 0.9832 - val_loss: 0.7039 - val_accuracy: 0.8187
# Epoch 11/100
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0772 - accuracy: 0.9876 - val_loss: 0.8142 - val_accuracy: 0.8216
# Epoch 12/100
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0579 - accuracy: 0.9905 - val_loss: 0.7752 - val_accuracy: 0.8216
# Epoch 13/100
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0474 - accuracy: 0.9905 - val_loss: 0.9021 - val_accuracy: 0.8070
# Epoch 14/100
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0518 - accuracy: 0.9890 - val_loss: 0.7626 - val_accuracy: 0.8363
# Epoch 15/100
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0443 - accuracy: 0.9927 - val_loss: 0.8230 - val_accuracy: 0.8304

# %% [markdown]
# ## 평가

# %%
model.evaluate(x_test_seq, y_test)
# Out:
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6525 - accuracy: 0.7804
# [0.6525000929832458, 0.7803738117218018]
